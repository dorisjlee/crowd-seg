# %%
cd TileEM/

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from TileEM_plot_toolbox import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd output/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/output

# %%
plot_all_postprocess_PR_curves(1,legend=True)

# %%
plot_all_postprocess_PR_curves(2,legend=True)

# %%
for objid in tqdm(object_lst):
    plot_all_postprocess_PR_curves(objid,legend=True)
# Out:
#  57%|█████▋    | 27/47 [14:15<10:33,  0.03it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-153c6fe95efd> in <module>()
#       1 for objid in tqdm(object_lst):
# ----> 2     plot_all_postprocess_PR_curves(objid,legend=True)
#
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/TileEM_plot_toolbox.py in plot_all_postprocess_PR_curves(objid, experiment_idx, legend)
#     139     Maj_topk_precision_lst = []
#     140     Maj_topk_recall_lst = []
# --> 141     for  k in k_lst :
#     142         Maj_topk_precision,Maj_topk_recall= compute_PR_obj(objid,experiment_idx,topk=k)
#     143         Maj_topk_precision_lst.append(Maj_topk_precision)
#
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/TileEM_plot_toolbox.py in compute_PR_obj(objid, experiment_idx, threshold, topk, majority_topk, PLOT_HEATMAP)
#     110             solnset = getSolutionTopK(tile_votes,k=majority_topk)
#     111             if PLOT_HEATMAP:
# --> 112                 mask = plot_tile_heatmap(objid,solnset ,tiles,tile_votes,PLOT_BBG=True,PLOT_GSOLN=True)
#     113         precision,recall = compute_PR(objid,solnset,tiles)
#     114         if PLOT_HEATMAP:
#
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/TileEM_plot_toolbox.py in compute_PR(objid, solnset, tiles)
#      30     x_locs,y_locs =  process_raw_locs([ground_truth_match["x_locs"].iloc[0],ground_truth_match["y_locs"].iloc[0]])
#      31     BBG = shapely.geometry.Polygon(zip(x_locs,y_locs))
# ---> 32     recall = ML_regions.intersection(BBG).area/float(BBG.area)
#      33     if float(ML_regions.area)!=0:
#      34         precision = ML_regions.intersection(BBG).area/float(ML_regions.area)
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/shapely/geometry/base.pyc in intersection(self, other)
#     618     def intersection(self, other):
#     619         """Returns the intersection of the geometries"""
# --> 620         return geom_factory(self.impl['intersection'](self, other))
#     621
#     622     def symmetric_difference(self, other):
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/shapely/geometry/base.pyc in geom_factory(g, parent)
#      76         raise ValueError("No Shapely geometry can be created from null value")
#      77     ob = BaseGeometry()
# ---> 78     geom_type = geometry_type_name(g)
#      79     # TODO: check cost of dynamic import by profiling
#      80     mod = __import__(
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/shapely/geometry/base.pyc in geometry_type_name(g)
#      68     if g is None:
#      69         raise ValueError("Null geometry has no type")
# ---> 70     return GEOMETRY_TYPES[lgeos.GEOSGeomTypeId(g)]
#      71
#      72
#
# KeyboardInterrupt:

# %%
for objid in tqdm(object_lst):
    plot_all_T_search_PR_curves(objid,'majority-top-k')
    plot_all_T_search_PR_curves(objid,'tile-threshold')
    plot_all_T_search_PR_curves(objid,'tile-top-k')
# Out:
#  96%|█████████▌| 45/47 [3:39:47<09:46,  0.00it/s]
