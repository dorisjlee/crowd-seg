# %%
cd TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from BB2TileExact import *
from TileEM_plot_toolbox import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd output
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/output

# %%
def join_tiles(solutionList,tiles): 
    '''
    Given a solutionList of tile indicies, join the tiles together into a Polygon/MultiPolygon object.
    '''
    try:
        return cascaded_union([tiles[tidx] for tidx in solutionList])
    except:
        #slow version, run through and exclude problematic solutionset item
        Utile=tiles[0]
        problematic_tiles =[]
        for soln in solutionList:
            try:
                Utile=Utile.union(tiles[soln])
            except(shapely.geos.TopologicalError):
                problematic_tiles.append(tiles[soln])
        problematic_tiles.append(Utile)
        return problematic_tiles

# %%
def intersection_area(poly1,poly2):
    try:
        return poly1.intersection(poly2).area
    except(shapely.geos.TopologicalError):
        return poly1.buffer(1e-5).intersection(poly2.buffer(1e-5)).area

# %%
def PR_compare(objid,sampleNworkers=40):    
    os.chdir("..")
    worker_lst,tiles,indicatorMat= createObjIndicatorMatrix(objid,PRINT=True,sampleNworkers=sampleNworkers,tqdm_on=False,tile_only=False)
    os.chdir(DATA_DIR)
    
    worker_precision_lst,worker_recall_lst = compute_worker_lst_PR_obj(objid,worker_lst)
    best_worker =  np.argmax(worker_recall_lst)
    print "Best worker's PR against BBG: ", max(worker_precision_lst),max(worker_recall_lst)

    approved_tiles = np.where(indicatorMat[best_worker]==1)[0]
    for tidx in approved_tiles:
        plot_coords(tiles[tidx],color="lime")

    bb_objects = bb_info[bb_info["object_id"]==objid]
    bb_objects =  bb_objects[bb_objects.worker_id!=3]
    
    best_worker_id = worker_lst[best_worker]
    worker_bb_info = bb_objects[bb_objects["worker_id"]==best_worker_id]
    worker_BB_polygon = Polygon(zip(*process_raw_locs([worker_bb_info["x_locs"].values[0],worker_bb_info["y_locs"].values[0]])))#.buffer(0)

    plot_coords(worker_BB_polygon,linestyle='--',color='#0000ff')
    
    joined_bb = join_tiles(approved_tiles,tiles)

    if type(joined_bb)==list:
        intersect_area =0
        joined_bb_area =0
        for jbb in joined_bb:
            ia = intersection_area(worker_BB_polygon,jbb)
            intersect_area += ia
            joined_bb_area += jbb.area
    else:
        intersect_area=intersection_area(worker_BB_polygon,joined_bb)
        joined_bb_area =joined_bb.area
    precision = intersect_area/joined_bb_area
    recall = intersect_area/worker_BB_polygon.area
    print precision,recall
    return precision,recall

# %%
objid=1
p,r=PR_compare(objid,sampleNworkers=10)
# Out:
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (297.93 183.431, 268.723 267.307) and LINESTRING (293.583 195.915, 292.937 197.77) at 293.15174416654747 197.15396547042775
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (407 251.5, 407 251.5) and LINESTRING (407 251.5, 412.667 260) at 406.99999999999574 251.499999999995
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (287.581 239.71, 286.941 240.647) and LINESTRING (286.941 240.647, 287.932 239.373) at 286.94117647058852 240.64705882352902
# ERROR:shapely.geos:TopologyException: Input geom 1 is invalid: Self-intersection at or near point 256.14963503649642 283.66423357664229 at 256.14963503649642 283.66423357664229
# ERROR:shapely.geos:TopologyException: Input geom 1 is invalid: Self-intersection at or near point 256.14963503649642 283.66423357664229 at 256.14963503649642 283.66423357664229
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (361.491 171.623, 361.491 171.623) and LINESTRING (361.491 171.623, 361.491 171.623) at 361.49056603763972 171.6226415089854
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (416.324 267.432, 418 280) and LINESTRING (417.714 277.857, 417.714 277.857) at 417.71428571428572 277.85714285714295
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (302.692 167.077, 302.623 167.321) and LINESTRING (302.623 167.321, 302.163 168.928) at 302.62257564321425 167.32098524875025
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (281.153 249.118, 286.941 240.647) and LINESTRING (282 247, 286.941 240.647) at 286.94117647058823 240.64705882352942
# Number of non-overlapping tile regions (M) :  463
# Number of workers (N) :  10
# all unvoted tiles: []
# all unvoted workers: []
# Object  1
# Check that there are no all-zero rows in indicator matrix: True
# Check that there are no all-zero columns in indicator matrix: True
# Best worker's PR against BBG:  0.944169228157 0.986213800212
# 170
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (216.24 300.02, 216.24 300.02) and LINESTRING (216.24 300.02, 216.24 300.02) at 216.24000000000015 300.01999999999998
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (201.368 306.526, 201.368 306.526) and LINESTRING (201.368 306.526, 197.151 307.37) at 201.36842105263176 306.52631578947364
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (227 297.714, 227 297.714) and LINESTRING (232.8 296.057, 227 297.714) at 226.99999999933331 297.7142857144762
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (226 298, 226.213 297.947) and LINESTRING (226.8 297.8, 226 298) at 226.00032520325246 297.99991869918688
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (401.32 244.432, 401.974 245.636) and LINESTRING (401.812 245.339, 401.787 245.292) at 401.80002056333973 245.31582735352046
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (262.717 276.166, 262.592 276.28) and LINESTRING (262.668 276.169, 258.632 282.076) at 262.59200000000016 276.27999999999986
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (362.545 185.909, 362.272 177.434) and LINESTRING (362 184, 362.545 185.909) at 362.54545454545456 185.90909090909082
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (340.25 149.5, 348 154.667) and LINESTRING (342.5 151, 342.5 151) at 342.5 151
# ERROR:shapely.geos:TopologyException: side location conflict at 365 214
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (340.889 149.136, 341.586 149.678) and LINESTRING (341.586 149.678, 340.5 148.833) at 341.163582988055 149.34945343515389
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (362.272 177.434, 359.776 167.948) and LINESTRING (359.776 167.948, 362 176.4) at 360.18029418733056 169.48511791185626
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (362.272 177.434, 359.776 167.948) and LINESTRING (362 176.4, 362 176.4) at 362 176.39999999998531
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (362.272 177.434, 359.776 167.948) and LINESTRING (362 176.4, 362 176.4) at 362 176.39999999998534
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (412 307, 411.816 308.224) and LINESTRING (415.406 296.02, 411.816 308.224) at 411.81632653061223 308.22448979591849
# 0.987272441449 1.16793519437

# %%
p,r=PR_compare(objid,sampleNworkers=5)
# Out:
# ERROR:shapely.geos:TopologyException: Input geom 1 is invalid: Self-intersection at or near point 419.92307692307702 280.30769230769192 at 419.92307692307702 280.30769230769192
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (417.1 273.25, 417.1 273.25) and LINESTRING (417.1 273.25, 417.1 273.25) at 417.09999999999997 273.24999999999983
# Number of non-overlapping tile regions (M) :  215
# Number of workers (N) :  5
# all unvoted tiles: []
# all unvoted workers: []
# Object  1
# Check that there are no all-zero rows in indicator matrix: True
# Check that there are no all-zero columns in indicator matrix: True
# Best worker's PR against BBG:  0.189157868605 0.978750360982
# 201
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (416 291, 411.556 318.222) and LINESTRING (411.556 318.222, 411.556 318.222) at 411.5555555555556 318.22222222222194
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (299.118 226.941, 293 234) and LINESTRING (296.539 229.916, 293.171 233.803) at 294.95615768511351 231.74289497871516
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (364 201, 364.8 202.8) and LINESTRING (364.8 202.8, 361 199) at 364.80000000000001 202.79999999999993
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (411.556 318.222, 411.556 318.222) and LINESTRING (416 291, 411.556 318.222) at 411.5555555555556 318.22222222222194
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (302.466 208.154, 302.453 208.392) and LINESTRING (302.477 207.943, 302.452 208.419) at 302.45347267640796 208.38401914824883
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (409 331, 409.538 328.308) and LINESTRING (409.538 328.308, 408.367 331.119) at 409.53846153846155 328.30769230769243
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (335.287 375.055, 327.333 371.385) and LINESTRING (327.333 371.385, 323.603 368.802) at 327.33333333333331 371.38461538461536
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (264.448 335.103, 265.753 335.647) and LINESTRING (264.448 335.103, 265.749 335.646) at 265.73022544661939 335.63759393609143
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (301.809 170.907, 301.324 175.765) and LINESTRING (301.324 175.765, 305 164) at 301.3235294117647 175.76470588235284
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (364 201, 364.8 202.8) and LINESTRING (364.8 202.8, 361 199) at 364.80000000000001 202.79999999999993
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (364.947 181.632, 364.947 181.632) and LINESTRING (364.947 181.632, 364.947 181.632) at 364.94736842105266 181.63157894736833
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (261.286 346.571, 260 344) and LINESTRING (260 344, 261.286 346.571) at 260 344
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (256.405 321.929, 256.734 322.018) and LINESTRING (256.406 321.929, 256.014 321.822) at 256.40557904991397 321.92879428634012
# ERROR:shapely.geos:TopologyException: side location conflict at 260 322
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (394.833 235.083, 391.91 233.037) and LINESTRING (391.91 233.037, 394.833 235.083) at 393.37081381775351 234.05956967242744
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (364.091 199.273, 364 201) and LINESTRING (364.091 199.273, 364.091 199.273) at 364.09090909090907 199.27272727272725
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (301.913 169.87, 301.913 169.87) and LINESTRING (301.913 169.87, 301.913 169.87) at 301.91304347826087 169.86956521739134
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (201 305, 197.333 305.333) and LINESTRING (202 303, 197.333 305.333) at 197.33333333333337 305.33333333333331
# 0.99645298648 0.988198277327

# %%
objid=15
p,r=PR_compare(objid,sampleNworkers=5)
# Out:
# Number of non-overlapping tile regions (M) :  34
# Number of workers (N) :  5
# all unvoted tiles: []
# all unvoted workers: []
# Object  15
# Check that there are no all-zero rows in indicator matrix: True
# Check that there are no all-zero columns in indicator matrix: True
# Best worker's PR against BBG:  0.84354217459 1.0
# 1.0 1.0

# %% [markdown]
# ### Running Evaluation based on created tile and indMats

# %%
def PR_compare(tiles,worker_lst,indicatorMat,objid,sampleNworkers=40,save_png=False):        
    worker_precision_lst,worker_recall_lst = compute_worker_lst_PR_obj(objid,worker_lst)
    best_worker =  np.argmax(worker_recall_lst)
    print "Best worker's PR against BBG: ", max(worker_precision_lst),max(worker_recall_lst)
    plt.figure()
    plt.title("Obj {}".format(objid))
    approved_tiles = np.where(indicatorMat[best_worker]==1)[0]
    for tidx in approved_tiles:
        plot_coords(tiles[tidx],color="lime")

    bb_objects = bb_info[bb_info["object_id"]==objid]
    bb_objects =  bb_objects[bb_objects.worker_id!=3]
    
    best_worker_id = worker_lst[best_worker]
    worker_bb_info = bb_objects[bb_objects["worker_id"]==best_worker_id]
    worker_BB_polygon = Polygon(zip(*process_raw_locs([worker_bb_info["x_locs"].values[0],worker_bb_info["y_locs"].values[0]])))#.buffer(0)

    plot_coords(worker_BB_polygon,linestyle='--',color='#0000ff')
    
    joined_bb = join_tiles(approved_tiles,tiles)

    if type(joined_bb)==list:
        intersect_area =0
        joined_bb_area =0
        for jbb in joined_bb:
            ia = intersection_area(worker_BB_polygon,jbb)
            intersect_area += ia
            joined_bb_area += jbb.area
    else:
        intersect_area=intersection_area(worker_BB_polygon,joined_bb)
        joined_bb_area =joined_bb.area
    precision = intersect_area/joined_bb_area
    recall = intersect_area/worker_BB_polygon.area
    print precision,recall
    if save_png:
        plt.savefig("best_obj{}_PR.png".format())
    return precision,recall

# %%
# objid = 1
sampleNworkers=10
p_lst =[]
r_lst =[]
for objid in tqdm(object_lst):
    os.chdir("../sample10/")
    tiles = pkl.load(open("tiles{}.pkl".format(objid),'r'))
    worker_lst= pkl.load(open("worker{}.pkl".format(objid),'r'))
    indicatorMat = pkl.load(open("indMat{}.pkl".format(objid),'r'))
    os.chdir("../"+DATA_DIR)
    p,r = PR_compare(tiles,worker_lst,indicatorMat,objid,sampleNworkers)    
    p_lst.append(p)
    r_lst.append(r)
# Out:
#   0%|          | 0/47 [00:00<?, ?it/s]ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (302 171, 300.571 174.714) and LINESTRING (300.571 174.714, 300.571 174.714) at 300.57142857142861 174.71428571428564
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (183.182 313.364, 184.429 312.429) and LINESTRING (184.429 312.429, 183 313) at 184.42857142857139 312.42857142857144
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (366.182 205.909, 366.462 206.538) and LINESTRING (366.792 207.64, 366 205) at 366.46153846153845 206.53846153846155
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (366.938 209.688, 366.781 208.905) and LINESTRING (366.538 207.692, 366.938 209.688) at 366.87755552292913 209.38777761464553
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (393 235, 393.909 235.727) and LINESTRING (393.909 235.727, 393.909 235.727) at 393.90909090909042 235.72727272727229
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (264.171 360.073, 265.611 366.313) and LINESTRING (264.667 362.222, 268 365) at 264.66666666666669 362.22222222222223
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (260.765 353.473, 259.053 342.342) and LINESTRING (260.909 352.636, 260.714 353.143) at 260.71428571428572 353.14285714285711
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (400.087 241.782, 398.2 239.267) and LINESTRING (400.923 241.385, 394 236) at 398.19999999999993 239.26666666666662
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (299.712 179.322, 299.818 177.727) and LINESTRING (299.712 179.322, 299.818 177.727) at 299.80852668791874 177.87209968121854
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (306 221.375, 306 220.4) and LINESTRING (306.448 221.207, 303.326 215.587) at 306 220.40000000000001
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (189.372 311.896, 184.533 313.933) and LINESTRING (188.909 312.091, 188.909 312.091) at 188.90909090909093 312.09090909090907
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (415 262, 413.844 260.222) and LINESTRING (413.844 260.222, 415.095 262.455) at 413.84444444444472 260.22222222222263
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (398.2 239.267, 398.5 239.5) and LINESTRING (400.923 241.385, 398.2 239.267) at 398.46748086411958 239.47470733875966
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (188.028 323.706, 185.185 319.6) and LINESTRING (187.824 323.412, 187.824 323.412) at 187.8235294117647 323.41176470588238
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (193.692 305.872, 193.692 305.872) and LINESTRING (193.692 305.872, 193.692 305.872) at 193.69230769230765 305.87179487179486
# ERROR:shapely.geos:TopologyException: side location conflict at 183.70476194563477 321.35238097281734
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (101.105 205.068, 58.3514 206.595) and LINESTRING (64 206, 58.3514 206.595) at 58.351351351351397 206.59459459459458
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (102.664 205.23, 101.105 205.338) and LINESTRING (101.43 205.315, 101.93 205.281) at 101.85125060246379 205.28612064810596
#  0.999828254118 0.974801026442
# 0.997798101031
#  96%|█████████▌| 45/47 [06:33<00:17,  0.11it/s]
#  1.1230064406
# Best worker's PR against BBG:
# ERROR:shapely.geos:TopologyException: Input geom 0 is invalid: Self-intersection at or near point 161.63636365227276 332.27272727954551 at 161.63636365227276 332.27272727954551
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (152 362, 154.189 361.514) and LINESTRING (153.385 361.692, 149 363.571) at 153.38461538461542 361.69230769230768
# ERROR:shapely.geos:TopologyException: side location conflict at 147 308
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (103.778 433, 105.905 430.265) and LINESTRING (105.682 430.552, 105.839 430.35) at 105.80427566162734 430.39450272076482
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (96.4 330.6, 101.636 327.545) and LINESTRING (101.636 327.545, 98.2857 329.5) at 100.37762237762232 328.27972027972032
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (154.391 361.261, 153.385 361.692) and LINESTRING (154.189 361.514, 153.385 361.692) at 153.38461538461564 361.69230769230762
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (154.386 361.263, 153.385 361.692) and LINESTRING (154.185 361.514, 152 362) at 153.38461538461567 361.69230769230762
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (93.4444 335.111, 93.7 334.6) and LINESTRING (93.4444 335.111, 94.6667 332.667) at 93.44444444444342 335.11111111111319
# ERROR:shapely.geos:TopologyException: side location conflict at 137 367
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (88 391, 92.2094 396.145) and LINESTRING (89.3235 392.618, 89.1429 391.714) at 89.32352941176471 392.61764705882354
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (96.4 330.6, 99.7019 328.674) and LINESTRING (106 325, 98.9603 329.106) at 99.141338902827371 329.00088564001737
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (93.7 334.6, 93.4444 335.111) and LINESTRING (91.1429 339.714, 93.6263 334.747) at 93.444444444444429 335.11111111111114
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (93.7 334.6, 93.4444 335.111) and LINESTRING (91.1429 339.714, 93.6263 334.747) at 93.444444444444429 335.11111111111114
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (94.715 398.85, 94.715 398.85) and LINESTRING (94.715 398.85, 94.6955 399.045) at 94.71500000000033 398.84999999999673
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (93.7 334.6, 93.4444 335.111) and LINESTRING (91.1429 339.714, 93.6263 334.747) at 93.444444444444429 335.11111111111114
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (93.7 334.6, 93.4444 335.111) and LINESTRING (91.1429 339.714, 93.6263 334.747) at 93.444444444444429 335.11111111111114
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (133.344 374.267, 131.709 376.583) and LINESTRING (133.556 372.889, 131.709 376.583) at 131.70857606225863 376.58284787548325
# ERROR:shapely.geos:TopologyException: EdgeRing::computePoints: found null Directed Edge
# ERROR:shapely.geos:TopologyException: side location conflict at 149 323
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (114.256 300.538, 116 294) and LINESTRING (114.256 300.538, 114.256 300.538) at 114.25641025641031 300.53846153846172
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (91.1429 339.714, 92.2906 337.419) and LINESTRING (91.1429 339.714, 92.291 337.418) at 91.142857142857139 339.71428571428572
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (154.391 361.261, 153.385 361.692) and LINESTRING (154.189 361.514, 153.385 361.692) at 153.38461538461561 361.69230769230762
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (137.425 367.993, 137.441 368.029) and LINESTRING (137.441 368.029, 137.419 367.978) at 137.43927162197247 368.02496711793577
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (147 362, 147.003 362) and LINESTRING (147.014 361.998, 147 362) at 147.00074060601912 361.99991771044233
# ERROR:shapely.geos:TopologyException: side location conflict at 125.75 390.5
#  0.959520429762 0.968364430391
# 0.923341175833
#  98%|█████████▊| 46/47 [06:39<00:08,  0.12it/s]ERROR:shapely.geos:TopologyException: Input geom 0 is invalid: Self-intersection at or near point 168 136.19999999999999 at 168 136.19999999999999
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (202.529 178.294, 195.6 177.2) and LINESTRING (196.572 177.275, 195.6 177.2) at 195.60000000000016 177.19999999999999
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (171 174, 173.168 174.526) and LINESTRING (172 174, 171.967 174.234) at 171.96652719665272 174.23430962343096
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (210.471 140.765, 208.273 160.545) and LINESTRING (208.273 160.545, 209.143 152.714) at 208.81869566008223 155.6317390592599
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (179.606 124.939, 179.606 124.939) and LINESTRING (178.913 124.833, 179.606 124.939) at 179.60606060606062 124.93939393939394
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (184.043 120.915, 184.182 120.636) and LINESTRING (184.043 120.915, 185 119) at 184.04255319148936 120.91489361702128
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (210.8 132.2, 211 129) and LINESTRING (210.8 132.2, 210.865 130.508) at 210.80000000000007 132.19999999999862
# ERROR:shapely.geos:TopologyException: side location conflict at 170 125
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (168 135, 167.958 136.667) and LINESTRING (167.958 136.667, 168 136.2) at 167.95833333333334 136.66666666666666
# ERROR:shapely.geos:TopologyException: no outgoing dirEdge found at 167.83606557377038 133.19672131147408
# ERROR:shapely.geos:TopologyException: no outgoing dirEdge found at 206.65040193125623 178.10679991221562
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (202.529 178.294, 195.6 177.2) and LINESTRING (195.6 177.2, 195.6 177.2) at 195.59999999999999 177.19999999999999
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (207.82 165.613, 207.446 169.807) and LINESTRING (207.711 166.842, 207.82 165.613) at 207.76107425462664 166.27596834818166
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (195.6 177.2, 195.6 177.2) and LINESTRING (195.6 177.2, 195.6 177.2) at 195.59999999999951 177.19999999999996
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (202.529 178.294, 195.6 177.2) and LINESTRING (195.6 177.2, 195.6 177.2) at 195.59999999999999 177.19999999999999
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (208 163, 207.959 163.658) and LINESTRING (207.959 163.658, 208.815 157.775) at 207.95890410958904 163.65753424657527
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (179.606 124.939, 178.471 124.765) and LINESTRING (178.709 124.781, 178.471 124.765) at 178.47058823529414 124.76470588235294
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (209 156.5, 208.187 178.037) and LINESTRING (207.057 178.088, 208.187 178.037) at 208.1872852233677 178.03694158075601
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (206.017 182.322, 206 182.333) and LINESTRING (206.017 182.322, 205.964 182.31) at 206.01694915254234 182.32203389830511
#  0.974437628412
# Best worker's PR against BBG:  0.989379635406 0.991618113381
# 0.971068428573
#  1.00829996506

# %%
plt.plot(p_lst,color="blue",label="Precision")
plt.plot(r_lst,color="red",label="Recall")

# %%
print "Average precision" ,mean(p_lst)
print "Average recall" , mean(r_lst)
# Out:
# Average precision 0.982028504284
# Average recall 1.49072844821

# %% [markdown]
# recall > 1 because intersection algorithm probably screwed up

# %%
tiles = pkl.load(open("../tiles13.pkl",'r'))
worker = pkl.load(open("../worker13.pkl",'r'))
imat = pkl.load(open("../indMat13.pkl",'r'))

# %%
sanity_check(imat,PLOT=True)
# Out:
# Check that there are no all-zero rows in indicator matrix: True
# Check that there are no all-zero columns in indicator matrix: True

# %%
len(tiles)
# Out:
# 3013

# %%
visualizeTiles(tiles)
