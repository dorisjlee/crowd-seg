# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %load_ext autoreload
# %autoreload 2
from analysis_toolbox import *

# %% [markdown]
# #### The null hypothesis is that the sample is not drawn from the reference distribution, so if p>0.05 then reject null hypothesis, they are drawn from that distribution. [see stats_helper.py]

# %%
def pcheck(p,null_hyp):
    '''
    if p>0.05 then reject null hypothesis
    '''
    if p>0.05:
        return  null_hyp
    else:
        return "NOT "+null_hyp

# %%
def one_way_kolmogorov_smirnov(data,name,distr_name):
	'''
	See if data come from the reference distribution
	'''
	result = stats.kstest(data,distr_name)
	print "{0} : D = {1} ; p ={2} ---> {3}".format(name,np.around(result[0],2),np.around(result[1],2),pcheck(result[1],"from {} distribution".format(distr_name)))

# %%
def basic_stats(data1,data2,mode="double"):
	print "Precision: mu = {0}; std = {1}".format(np.around(mean(data1),3),np.around(std(data1),3))
	if mode=="double": print "Recall: mu = {0}; std = {1}".format(np.around(mean(data2),3),np.around(std(data2),3))

# %%
def basic_stat(data1,name):
	print "{0}: mu = {1}; std = {2}".format(name,np.around(mean(data1),3),np.around(std(data1),3))
	return [name,np.around(mean(data1),3),np.around(std(data1),3)]

# %%
from scipy.stats import *

# %%
from tabulate import tabulate

# %%
bb_info = pd.read_csv('computed_my_COCO_BBvals.csv')
metrics_lst = ['Precision [COCO]','Recall [COCO]','Jaccard [COCO]',\
               'Precision [Self]','Recall [Self]','Jaccard [Self]']
FILTER_CRITERION=0
NUM_COL = 3
NUM_ROW = 2
NUM_PLOTS = NUM_COL*NUM_ROW

fig, axs = plt.subplots(NUM_ROW,NUM_COL, figsize=(NUM_ROW*3,NUM_COL*1.5), sharex='col')
fig.suptitle("All Worker Metric Distribution ".format(FILTER_CRITERION),fontsize=16,y=1.05)

axs = axs.ravel()
table_data = []
for i,metric in zip(range(len(metrics_lst)),metrics_lst):
    metric_value = np.array(bb_info[metric][bb_info[metric]>0][bb_info[metric]<=1]) 
    table_data.append(basic_stat(metric_value,metric))
    ax = axs[i]
    ax.set_title(metric)
    ax.hist(metric_value,bins=50)
    ax.set_xlim(0,1.03)
fig.tight_layout()
fig.savefig('metric_histogram.pdf')
# Out:
# Precision [COCO]: mu = 0.869; std = 0.227
# Recall [COCO]: mu = 0.897; std = 0.132
# Jaccard [COCO]: mu = 0.789; std = 0.227
# Precision [Self]: mu = 0.864; std = 0.206
# Recall [Self]: mu = 0.901; std = 0.145
# Jaccard [Self]: mu = 0.785; std = 0.219

# %%
print tabulate(table_data,headers=["All","Mean","SD"],tablefmt='latex')
# Out:
# \begin{tabular}{lrr}
# \hline
#  All              &   Mean &    SD \\
# \hline
#  Precision [COCO] &  0.869 & 0.227 \\
#  Recall [COCO]    &  0.897 & 0.132 \\
#  Jaccard [COCO]   &  0.789 & 0.227 \\
#  Precision [Self] &  0.864 & 0.206 \\
#  Recall [Self]    &  0.901 & 0.145 \\
#  Jaccard [Self]   &  0.785 & 0.219 \\
# \hline
# \end{tabular}

# %% [markdown]
# # Good Worker's Measures

# %%
metrics_lst = ['Precision [COCO]','Recall [COCO]','Jaccard [COCO]',\
               'Precision [Self]','Recall [Self]','Jaccard [Self]']
FILTER_CRITERION = 0.6
NUM_COL = 3
NUM_ROW = 2
NUM_PLOTS = NUM_COL*NUM_ROW

fig, axs = plt.subplots(NUM_ROW,NUM_COL, figsize=(NUM_ROW*3,NUM_COL*1.5), sharex='col')
fig.suptitle("Good Worker [metric >{}]".format(FILTER_CRITERION),fontsize=16,y=1.05)
# fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

table_data = []
for i,metric in zip(range(len(metrics_lst)),metrics_lst):
    metric_value = np.array(bb_info[metric][bb_info[metric]>FILTER_CRITERION][bb_info[metric]<=1]) 
    table_data.append(basic_stat(metric_value,metric))
    ax = axs[i]
    ax.set_title(metric)
    ax.hist(metric_value,bins=30)
    ax.set_xlim(FILTER_CRITERION,1.03)
    #Testing against various distributions 
    for test_distr in ['expon','norm','cauchy']:
        one_way_kolmogorov_smirnov(metric_value,'COCO Precision',test_distr)
fig.tight_layout()
fig.savefig('good_worker_metric_histogram.pdf')
# Out:
# Precision [COCO]: mu = 0.931; std = 0.068
# COCO Precision : D = 0.5 ; p =0.0 ---> NOT from expon distribution
# COCO Precision : D = 0.75 ; p =0.0 ---> NOT from norm distribution
# COCO Precision : D = 0.69 ; p =0.0 ---> NOT from cauchy distribution
# Recall [COCO]: mu = 0.917; std = 0.07
# COCO Precision : D = 0.49 ; p =0.0 ---> NOT from expon distribution
# COCO Precision : D = 0.74 ; p =0.0 ---> NOT from norm distribution
# COCO Precision : D = 0.68 ; p =0.0 ---> NOT from cauchy distribution
# Jaccard [COCO]: mu = 0.858; std = 0.082
# COCO Precision : D = 0.46 ; p =0.0 ---> NOT from expon distribution
# COCO Precision : D = 0.73 ; p =0.0 ---> NOT from norm distribution
# COCO Precision : D = 0.67 ; p =0.0 ---> NOT from cauchy distribution
# Precision [Self]: mu = 0.918; std = 0.076
# COCO Precision : D = 0.49 ; p =0.0 ---> NOT from expon distribution
# COCO Precision : D = 0.74 ; p =0.0 ---> NOT from norm distribution
# COCO Precision : D = 0.67 ; p =0.0 ---> NOT from cauchy distribution
# Recall [Self]: mu = 0.925; std = 0.073
# COCO Precision : D = 0.48 ; p =0.0 ---> NOT from expon distribution
# COCO Precision : D = 0.74 ; p =0.0 ---> NOT from norm distribution
# COCO Precision : D = 0.68 ; p =0.0 ---> NOT from cauchy distribution
# Jaccard [Self]: mu = 0.858; std = 0.086
# COCO Precision : D = 0.46 ; p =0.0 ---> NOT from expon distribution
# COCO Precision : D = 0.73 ; p =0.0 ---> NOT from norm distribution
# COCO Precision : D = 0.67 ; p =0.0 ---> NOT from cauchy distribution

# %%
print tabulate(table_data,headers=["Mean","SD"],tablefmt='latex')
# Out:
# \begin{tabular}{lrr}
# \hline
#                   &   Mean &    SD \\
# \hline
#  Precision [COCO] &  0.931 & 0.068 \\
#  Recall [COCO]    &  0.917 & 0.07  \\
#  Jaccard [COCO]   &  0.858 & 0.082 \\
#  Precision [Self] &  0.918 & 0.076 \\
#  Recall [Self]    &  0.925 & 0.073 \\
#  Jaccard [Self]   &  0.858 & 0.086 \\
# \hline
# \end{tabular}

# %% [markdown]
# The key difference between directly using a one way kolomogorov smirnov test against some given pdf is that the parameters of that pdf is not fitted. So instead what we should do is fit the function first, then conduct a two-way KS test on the fitted data and the actual data to see if the distributions are the same (and whether that is statistically significant. The fitting is done with the MLE parameters. We exclude the ones that don't have fitting function implemented.

# %%
def kolmogorov_smirnov(data1,data2,name):
	'''
	Two-way KS test . See if data come from the same distribution
	'''
	result = stats.ks_2samp(data1,data2)
	if result[1]>0.05: print "{0} : D = {1} ; p ={2} ---> {3}".format(name,np.around(result[0],2),np.around(result[1],2),pcheck(result[1],"from same distribution"))
	return result

# %% [markdown]
# Test this against all distributions

# %%
print dir(stats.distributions)[9:]
# Out:
# ['alpha', 'anglit', 'arcsine', 'bernoulli', 'beta', 'betaprime', 'binom', 'boltzmann', 'bradford', 'burr', 'cauchy', 'chi', 'chi2', 'cosine', 'dgamma', 'division', 'dlaplace', 'dweibull', 'entropy', 'erlang', 'expon', 'exponpow', 'exponweib', 'f', 'fatiguelife', 'fisk', 'foldcauchy', 'foldnorm', 'frechet_l', 'frechet_r', 'gamma', 'gausshyper', 'genexpon', 'genextreme', 'gengamma', 'genhalflogistic', 'genlogistic', 'genpareto', 'geom', 'gilbrat', 'gompertz', 'gumbel_l', 'gumbel_r', 'halfcauchy', 'halflogistic', 'halfnorm', 'hypergeom', 'hypsecant', 'invgamma', 'invgauss', 'invweibull', 'johnsonsb', 'johnsonsu', 'ksone', 'kstwobign', 'laplace', 'levy', 'levy_l', 'levy_stable', 'loggamma', 'logistic', 'loglaplace', 'lognorm', 'logser', 'lomax', 'maxwell', 'mielke', 'nakagami', 'nbinom', 'ncf', 'nct', 'ncx2', 'norm', 'pareto', 'pearson3', 'planck', 'poisson', 'powerlaw', 'powerlognorm', 'powernorm', 'print_function', 'randint', 'rayleigh', 'rdist', 'recipinvgauss', 'reciprocal', 'rice', 'rv_continuous', 'rv_discrete', 'rv_frozen', 'semicircular', 'skellam', 't', 'triang', 'truncexpon', 'truncnorm', 'tukeylambda', 'uniform', 'vonmises', 'vonmises_line', 'wald', 'weibull_max', 'weibull_min', 'wrapcauchy', 'zipf']

# %%
import scipy.stats

# %%
exclude= ['division', 'skellam', 'nbinom', 'logser', 'erlang','dlaplace', 'hypergeom', 'bernoulli', 'levy_stable', 'zipf', 'rv_discrete', 'rv_frozen', 'boltzmann', 'rv_continuous', 'entropy', 'randint', 'poisson', 'geom', 'binom', 'planck', 'print_function']

# %%
print filter(lambda x: x not in exclude,dir(stats.distributions)[9:])
# Out:
# ['alpha', 'anglit', 'arcsine', 'beta', 'betaprime', 'bradford', 'burr', 'cauchy', 'chi', 'chi2', 'cosine', 'dgamma', 'dweibull', 'expon', 'exponpow', 'exponweib', 'f', 'fatiguelife', 'fisk', 'foldcauchy', 'foldnorm', 'frechet_l', 'frechet_r', 'gamma', 'gausshyper', 'genexpon', 'genextreme', 'gengamma', 'genhalflogistic', 'genlogistic', 'genpareto', 'gilbrat', 'gompertz', 'gumbel_l', 'gumbel_r', 'halfcauchy', 'halflogistic', 'halfnorm', 'hypsecant', 'invgamma', 'invgauss', 'invweibull', 'johnsonsb', 'johnsonsu', 'ksone', 'kstwobign', 'laplace', 'levy', 'levy_l', 'loggamma', 'logistic', 'loglaplace', 'lognorm', 'lomax', 'maxwell', 'mielke', 'nakagami', 'ncf', 'nct', 'ncx2', 'norm', 'pareto', 'pearson3', 'powerlaw', 'powerlognorm', 'powernorm', 'rayleigh', 'rdist', 'recipinvgauss', 'reciprocal', 'rice', 'semicircular', 't', 'triang', 'truncexpon', 'truncnorm', 'tukeylambda', 'uniform', 'vonmises', 'vonmises_line', 'wald', 'weibull_max', 'weibull_min', 'wrapcauchy']

# %% [markdown]
# We find that trying to do datafitting with only filtered good workers is not great, it means most distributions doesn't fit (because outlier are not completely clean since most of these are long tail disstributions ).

# %%
bb_info = pd.read_csv('computed_my_COCO_BBvals.csv')
metrics_lst = ['Precision [COCO]','Recall [COCO]','Jaccard [COCO]',\
               'Precision [Self]','Recall [Self]','Jaccard [Self]']
FILTER_CRITERION = 0.6
NUM_COL = 3
NUM_ROW = 2
NUM_PLOTS = NUM_COL*NUM_ROW

fig, axs = plt.subplots(NUM_ROW,NUM_COL, figsize=(NUM_ROW*3,NUM_COL*1.5), sharex='col')
fig.suptitle("Good Worker [metric >{}]".format(FILTER_CRITERION),fontsize=16,y=1.05)
# fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

table_data = []
for i,metric in zip(range(len(metrics_lst)),metrics_lst):
    metric_value = np.array(bb_info[metric][bb_info[metric]>FILTER_CRITERION][bb_info[metric]<=1]) 
    table_data.append(basic_stat(metric_value,metric))
    ax = axs[i]
    ax.set_title(metric)
    ax.hist(metric_value,bins=30)
    ax.set_xlim(FILTER_CRITERION,1.03)
    #Testing against various distributions 
    
    for fcn_name in filter(lambda x: x not in exclude,dir(stats.distributions)[9:]):
        # Based on MLE estimate for fitting
        try:
            fcn = getattr(scipy.stats,fcn_name)
            params = fcn.fit(1-metric_value)
            histo,bins = np.histogram(1-metric_value, 30, normed=1)
            y = fcn.pdf(bins, *params)
            RSS =sum((bins-y)**2)
            R = np.corrcoef(bins,y)[0][1]
            print "RSS:",RSS
            print "R: ",R
            kolmogorov_smirnov(bins,y,fcn_name)
        except(AttributeError,NotImplementedError,TypeError):
            #function has no fitting
            print "Skipped", fcn_name
fig.tight_layout()
fig.savefig('good_worker_metric_histogram.pdf')
# Out:
# Precision [COCO]: mu = 0.931; std = 0.068
# RSS: 55.2710138862
# R:  0.49947367802
# RSS: 142.637493015
# R:  -0.787330268869
# RSS: 1.49644493524e+27
# R:  -0.306186217848
# RSS: 612003792.603
# R:  -0.306723289464
# RSS: 825.458385251
# R:  -0.774117283746
# RSS: 192.945094788
# R:  -0.967688941986
# RSS: 3.26638068962e+47
# R:  -0.306186217848
# RSS: 386.983908706
# R:  -0.747678425197
# RSS: 1.15172452336e+16
# R:  -0.306186337944
# RSS: 3.32547168588e+12
# R:  -0.306192706736
# RSS: 161.269840078
# R:  -0.89012497155
# RSS: 354.577519284
# R:  -0.849792821886
# RSS: 345.776455401
# R:  -0.843930502156
# RSS: 462.278693209
# R:  -0.744141818705
# RSS: 6.72928464266e+16
# R:  -0.306186267513
# RSS: 470.495423131
# R:  -0.743411442695
# RSS: 776.427835357
# R:  -0.782944278589
# RSS: 545.108320958
# R:  -0.77243864345
# RSS: 1.6276949456e+25
# R:  -0.30618621785
# RSS: 582.659978958
# R:  -0.794690048137
# RSS: 465.635469696
# R:  -0.924083601436
# RSS: 8.14995628975e+21
# R:  0.30618621791
# RSS: 463.510456327
# R:  -0.746670658459
# RSS: 18597.7702492
# R:  -0.405697120781
# RSS: 1.80101315273e+22
# R:  -0.306186217921
# RSS: 641.05650669
# R:  -0.829153828518
# RSS: 558.859380276
# R:  -0.769384284864
# RSS: 471.670525641
# R:  -0.74282821206
# RSS: 534.465591228
# R:  -0.886296820206
# RSS: 428.537144833
# R:  -0.860646122758
# RSS: 642.475459554
# R:  -0.832418909322
# RSS: 553.63541254
# R:  -0.765089131591
# RSS: 663.667380362
# R:  -0.822727352146
# RSS: 169.595116691
# R:  -0.87855251297
# RSS: 429.267009723
# R:  -0.860212708345
# RSS: 633.401620727
# R:  -0.764346554493
# RSS: 534.894293264
# R:  -0.886073479584
# RSS: 465.699300931
# R:  -0.924056741914
# RSS: 351.320174113
# R:  -0.845290563096
# RSS: 558.537310806
# R:  -0.773289420228
# RSS: 559.728272762
# R:  -0.771078973502
# RSS: nan
# R:  nan
# invweibull : D = 0.29 ; p =0.12 ---> from same distribution
# RSS: 510.332254621
# R:  -0.794183713213
# RSS: 554.660190671
# R:  -0.770206874067
# RSS: 168.511629822
# R:  -0.435908439855
# RSS: 395.975808618
# R:  -0.886951192161
# RSS: 363.358873773
# R:  -0.811660381033
# RSS: nan
# R:  nan
# RSS: nan
# R:  nan
# RSS: 284.478985844
# R:  -0.894663864189
# RSS: 339.022070607
# R:  -0.860196434491
# RSS: 2.41999224977e+38
# R:  -0.306186217848
# RSS: 554.534255317
# R:  -0.770337754273
# RSS: 861.321916046
# R:  -0.696520344072
# RSS: 345.364262706
# R:  -0.894270336875
# RSS: 5.05130526687e+22
# R:  -0.3061862179
# RSS: 1.82429269604e+16
# R:  -0.306186310943
# RSS: 3409.31065748
# R:  -0.459337750477
# RSS: 558.910887988
# R:  -0.772788139327
# RSS: 6.02120991012e+12
# R:  -0.306191666278
# RSS: 288.234592675
# R:  -0.893616528071
# RSS: 1.64580283273
# R:  nan
# RSS: inf
# R:  nan
# RSS: 1.72233294068e+27
# R:  -0.306186217848
# RSS: 530.235302388
# R:  -0.809289923715
# RSS: nan
# R:  nan
# RSS: 368.90419664
# R:  -0.896375094682
# RSS: 2.6068386056e+13
# R:  0.306182895739
# RSS: 518.67799819
# R:  -0.789814373934
# RSS: 1.64580283273
# R:  nan
# RSS: 368.817988499
# R:  -0.896425841126
# RSS: 143.816892718
# R:  -0.567172122322
# RSS: 390.735418752
# R:  -0.811806664065
# RSS: 249.376443743
# R:  -1.0
# RSS: 211.109359229
# R:  -0.983534930227
# RSS: 1.64580283273
# R:  nan
# RSS: 262.272191476
# R:  -0.866025403784
# RSS: 168.526190343
# R:  1.51745356634e-16
# RSS: 2.76112406477e+60
# R:  0.053669766424
# RSS: 401.134528345
# R:  -0.829852225085
# RSS: 558.999037028
# R:  -0.772461275809
# RSS: 8.14995628975e+21
# R:  0.30618621791
# RSS: 463.510456327
# R:  -0.746670658459
# RSS: nan
# R:  nan
# Recall [COCO]: mu = 0.917; std = 0.07
# RSS: 1006.26500311
# R:  -0.586739841565
# RSS: 157.924164297
# R:  -0.730655791449
# RSS: 7.85544687765e+29
# R:  -0.306186217848
# RSS: 417.261079056
# R:  -0.885967295595
# RSS: 420.644934516
# R:  -0.878410460167
# RSS: 216.858551841
# R:  -0.881621072513
# RSS: 2.93891049996e+42
# R:  -0.306186217848
# RSS: 332.079946087
# R:  -0.747620644712
# RSS: 1.99739656811e+12
# R:  -0.306194922563
# RSS: 1251.01551679
# R:  -0.678168310498
# RSS: 179.082564118
# R:  -0.845687158783
# RSS: 349.34923058
# R:  -0.822651839628
# RSS: 343.897094847
# R:  -0.822846665445
# RSS: 527.308962986
# R:  -0.865487320461
# RSS: 6.55626236731e+13
# R:  -0.306187700274
# RSS: 416.671122719
# R:  -0.896687243912
# RSS: 420.146044391
# R:  -0.878284170025
# RSS: 438.917101919
# R:  -0.836780544823
# RSS: 9.41259256465e+16
# R:  -0.306186244892
# RSS: 400.959999711
# R:  -0.861993660354
# RSS: 414.461556915
# R:  -0.95057118081
# RSS: 397.322196333
# R:  -0.857987611855
# RSS: 416.482086332
# R:  -0.901443097217
# RSS: 420.139807635
# R:  -0.878292656609
# RSS: 7.8352187917e+14
# R:  -0.306186539126
# RSS: 419.318907876
# R:  -0.803412479382
# RSS: 438.995801506
# R:  -0.826874241982
# RSS: 416.489011872
# R:  -0.898997338576
# RSS: 447.631548886
# R:  -0.925705074428
# RSS: 396.397342383
# R:  -0.858756988283
# RSS: 478.826682221
# R:  -0.905999703986
# RSS: 431.932430556
# R:  -0.799541786308
# RSS: 469.72061036
# R:  -0.914416634692
# RSS: 171.284303095
# R:  -0.837211743877
# RSS: 396.938027968
# R:  -0.858233201918
# RSS: 443.660568184
# R:  -0.833745396044
# RSS: 405.57843223
# R:  -0.81224260993
# RSS: 414.388188809
# R:  -0.950599205346
# RSS: 343.176269375
# R:  -0.829106521262
# RSS: 440.316862223
# R:  -0.828953428647
# RSS: 440.934625079
# R:  -0.834308247199
# RSS: 439.107511886
# R:  -0.826815294531
# RSS: 425.162179296
# R:  -0.850256787873
# RSS: 441.696594933
# R:  -0.831752577133
# RSS: 174.751139807
# R:  -0.54079899765
# RSS: 373.422190023
# R:  -0.880862954998
# RSS: 359.139429569
# R:  -0.786313937336
# RSS: 360.888944026
# R:  -0.636742686771
# RSS: nan
# R:  nan
# RSS: 283.838698168
# R:  -0.874734393035
# RSS: 335.102426814
# R:  -0.843189829234
# RSS: 1.6207200983e+35
# R:  -0.306186217848
# RSS: 441.407969045
# R:  -0.831607160762
# RSS: 518.101441401
# R:  -0.868282949406
# RSS: 337.484932371
# R:  -0.880167645259
# RSS: 6.29271874486e+40
# R:  -0.306186217848
# RSS: 2.13290958233e+16
# R:  -0.306186298061
# RSS: 430.593053405
# R:  -0.765795618697
# RSS: 439.790028823
# R:  -0.828480944497
# RSS: 3.38162790546e+20
# R:  -0.306186218423
# RSS: 287.784922456
# R:  -0.873146037526
# RSS: 1.59390441331
# R:  nan
# RSS: 420.123482331
# R:  -0.878307527311
# RSS: 1.50300138749e+19
# R:  -0.306186218911
# RSS: 429.012491174
# R:  -0.85866941565
# RSS: nan
# R:  nan
# RSS: 355.724766921
# R:  -0.885285979981
# RSS: 2.91124568161e+18
# R:  -0.306186219064
# RSS: 435.616168046
# R:  -0.840690114806
# RSS: 1.59390441331
# R:  nan
# RSS: 355.813851679
# R:  -0.885199464223
# RSS: 157.494435424
# R:  -0.493839804646
# RSS: 362.595293508
# R:  -0.815479352329
# RSS: 257.552557538
# R:  -1.0
# RSS: 203.198638035
# R:  -0.976407394502
# RSS: 1.59390441331
# R:  nan
# RSS: 260.756740799
# R:  -0.866025403784
# RSS: 174.907931065
# R:  -6.16784098013e-17
# RSS: 1.26554798277e+59
# R:  -0.0426537635158
# RSS: 324.241021348
# R:  -0.853011009011
# RSS: 446.378455488
# R:  -0.797264596954
# RSS: 397.322196333
# R:  -0.857987611855
# RSS: 416.482086332
# R:  -0.901443097217
# RSS: nan
# R:  nan
# Jaccard [COCO]: mu = 0.858; std = 0.082
# RSS: 289.715988103
# R:  -0.760452964074
# RSS: 187.184051554
# R:  -0.511019919829
# RSS: 6.24718336605e+15
# R:  0.306186019725
# RSS: 271.26216878
# R:  -0.859548834565
# RSS: 288.020001593
# R:  -0.80161510237
# RSS: 193.367656319
# R:  -0.975532726566
# RSS: 275.332964295
# R:  -0.861316039366
# RSS: 256.352537508
# R:  -0.634689923704
# RSS: 274.012413551
# R:  -0.858206664123
# RSS: 286.372550066
# R:  -0.807857393978
# RSS: 209.618646624
# R:  -0.641613584209
# RSS: 271.134582252
# R:  -0.660474564076
# RSS: 263.578254405
# R:  -0.684422653384
# RSS: 330.014394297
# R:  -0.930402897091
# RSS: 262.540933276
# R:  -0.926201745037
# RSS: 272.600520979
# R:  -0.861722231223
# RSS: 286.376204439
# R:  -0.807866063549
# RSS: 288.396092733
# R:  -0.785925189107
# RSS: 293.667490096
# R:  -0.746891113386
# RSS: 276.737152585
# R:  -0.782517479857
# RSS: 275.868511685
# R:  -0.968766942195
# RSS: 1.47291412901e+13
# R:  0.306188753683
# RSS: 281.072327527
# R:  -0.832776072914
# RSS: 286.371222106
# R:  -0.807858936993
# RSS: 254.633261669
# R:  -0.911310980971
# RSS: 279.055693157
# R:  -0.889476549988
# RSS: 290.098474431
# R:  -0.763095249635
# RSS: 272.798336747
# R:  -0.861739776095
# RSS: 285.646135025
# R:  -0.986516221415
# RSS: 288.620624906
# R:  -0.759187062438
# RSS: 280.659191579
# R:  -0.997235291083
# RSS: 265.372829045
# R:  -0.826144808681
# RSS: 273.679911534
# R:  -0.988474917306
# RSS: 180.907661893
# R:  -0.571690948926
# RSS: 288.668079481
# R:  -0.760103822294
# RSS: 245.937217164
# R:  -0.927301213044
# RSS: 297.148564685
# R:  -0.979776381148
# RSS: 291.937247028
# R:  -0.989449729441
# RSS: 268.241975786
# R:  -0.695185723363
# RSS: 289.808726446
# R:  -0.768859337523
# RSS: 288.650715902
# R:  -0.783347285051
# RSS: 290.087147692
# R:  -0.763098442879
# RSS: 274.320687166
# R:  -0.837146081275
# RSS: 289.030601047
# R:  -0.777188412438
# RSS: 164.882497579
# R:  -0.252168350876
# RSS: 282.515085692
# R:  -0.777727393394
# RSS: 284.81593092
# R:  -0.666299754215
# RSS: 173.361201692
# R:  -0.749534819581
# RSS: 1.74850158442
# R:  nan
# RSS: 243.721000482
# R:  -0.696442317853
# RSS: 261.845902513
# R:  -0.702544986045
# RSS: 309.615679144
# R:  -0.70305825451
# RSS: 289.345845978
# R:  -0.776920334168
# RSS: 330.175071153
# R:  -0.930354917308
# RSS: 271.154574429
# R:  -0.744553373673
# RSS: 275.334068491
# R:  -0.861320885172
# RSS: 274.010927913
# R:  -0.858307499142
# RSS: 147.224560192
# R:  -0.971619746276
# RSS: 290.273939005
# R:  -0.766207306329
# RSS: 360.884032901
# R:  -0.892581072481
# RSS: 247.201115534
# R:  -0.701404402213
# RSS: 1.74850158442
# R:  nan
# RSS: 286.370169518
# R:  -0.807868652564
# RSS: 161.292518049
# R:  -0.8952269562
# RSS: inf
# R:  nan
# RSS: nan
# R:  nan
# RSS: 277.018600105
# R:  -0.770867788397
# RSS: 246.917098692
# R:  -0.701165194935
# RSS: 288.267498421
# R:  -0.787622430948
# RSS: 1.74850158442
# R:  nan
# RSS: 277.023450637
# R:  -0.770950022578
# RSS: 179.411313092
# R:  -0.271396024757
# RSS: 255.092748903
# R:  -0.704320735621
# RSS: 239.803929308
# R:  -0.888176973604
# RSS: 212.935114497
# R:  -0.988399118071
# RSS: 1.74850158442
# R:  nan
# RSS: 242.379244297
# R:  -0.810092587301
# RSS: 180.239859858
# R:  -2.20048758105e-16
# RSS: 4.76402343056e+58
# R:  0.136150961863
# RSS: 264.297984427
# R:  -0.700330199026
# RSS: 274.530001481
# R:  -0.821065648249
# RSS: 1.47291412901e+13
# R:  0.306188753683
# RSS: 281.072327527
# R:  -0.832776072914
# RSS: nan
# R:  nan
# Precision [Self]: mu = 0.918; std = 0.076
# RSS: 100.822119893
# R:  -0.317203313701
# RSS: 146.626704761
# R:  -0.753411062032
# RSS: 4.24353547732e+27
# R:  -0.306186217848
# RSS: 401132765618.0
# R:  -0.30620568861
# RSS: 1.46340718065e+43
# R:  -0.306186217848
# RSS: 251.014602231
# R:  -0.891816498469
# RSS: 4.70497912532e+41
# R:  -0.306186217848
# RSS: 359.022320404
# R:  -0.750817030943
# RSS: 288667656.213
# R:  -0.306938667376
# RSS: 1.42033594431e+12
# R:  -0.306195573373
# RSS: 166.621022204
# R:  -0.863197661206
# RSS: 320.552397254
# R:  -0.832522775024
# RSS: 332.164013678
# R:  -0.811048510464
# RSS: 529.293191683
# R:  -0.857313349449
# RSS: 1.73449757462e+17
# R:  -0.306186245438
# RSS: inf
# R:  nan
# RSS: 1.03680993204e+17
# R:  -0.306186245412
# RSS: 433.300267124
# R:  -0.84819754194
# RSS: 2.79101256099e+31
# R:  -0.306186217848
# RSS: 461.069494367
# R:  -0.839539659514
# RSS: 395.776693223
# R:  -0.950434743026
# RSS: 2.0304031649e+17
# R:  0.306186235701
# RSS: 40321631.9811
# R:  -0.307787828606
# RSS: 2.25280334598e+32
# R:  -0.306186217848
# RSS: 7.43005388865e+24
# R:  -0.306186217851
# RSS: 490.507936761
# R:  -0.88640241161
# RSS: 441.402039374
# R:  -0.824988583248
# RSS: 789884200641.0
# R:  -0.306198081824
# RSS: 297.478331136
# R:  -0.971951555369
# RSS: 370.708081105
# R:  -0.877136872952
# RSS: 496.483358008
# R:  -0.882325104523
# RSS: 439.471977699
# R:  -0.821089577577
# RSS: 397.212845729
# R:  -0.952706339127
# RSS: 157.517737736
# R:  -0.845677121328
# RSS: 370.591112797
# R:  -0.877023709412
# RSS: 487.945468795
# R:  -0.808931142152
# RSS: 445.105752837
# R:  -0.918570591056
# RSS: 395.805048759
# R:  -0.950423393696
# RSS: 307.479194859
# R:  -0.857883343293
# RSS: 440.222846308
# R:  -0.83003873167
# RSS: 437.084662778
# R:  -0.841748711761
# RSS: nan
# R:  nan
# invweibull : D = 0.29 ; p =0.12 ---> from same distribution
# RSS: 420.390168165
# R:  -0.867038632376
# RSS: 438.734999588
# R:  -0.838706593567
# RSS: 165.82101231
# R:  -0.407268656478
# RSS: 345.108524602
# R:  -0.900073680627
# RSS: 323.550852336
# R:  -0.823152756076
# RSS: nan
# R:  nan
# RSS: nan
# R:  nan
# RSS: 248.390985411
# R:  -0.897528628019
# RSS: 295.313876428
# R:  -0.87113135694
# RSS: 1.31823973805e+28
# R:  -0.306186217848
# RSS: 438.387954375
# R:  -0.838803606951
# RSS: 650.26508211
# R:  -0.737152610622
# RSS: 304.195551485
# R:  -0.900620735404
# RSS: 7.49750909347e+44
# R:  -0.306186217848
# RSS: 3.06162432363e+21
# R:  -0.306186218037
# RSS: 1871.35908475
# R:  -0.582263893443
# RSS: 439.866901315
# R:  -0.828325227414
# RSS: 1.92851552645e+20
# R:  -0.306186218604
# RSS: 256.160495191
# R:  -0.893057492153
# RSS: 1.66868726345
# R:  nan
# RSS: inf
# R:  nan
# RSS: 1.79084871202e+29
# R:  -0.306186217848
# RSS: 434.662891041
# R:  -0.865983253443
# RSS: nan
# R:  nan
# RSS: 323.444751038
# R:  -0.904939062502
# RSS: 1.63258298531e+18
# R:  -0.306186216925
# RSS: 430.347065317
# R:  -0.856322446454
# RSS: 1.66868726345
# R:  nan
# RSS: 323.399068274
# R:  -0.90494544446
# RSS: 146.296372057
# R:  -0.525718657536
# RSS: 341.995646255
# R:  -0.825699613269
# RSS: 245.596935887
# R:  -1.0
# RSS: 197.571686969
# R:  -0.987906663635
# RSS: 1.66868726345
# R:  nan
# RSS: 223.372420423
# R:  -0.866025403784
# RSS: 165.835381073
# R:  -3.01402488363e-17
# RSS: 7.23631939845e+59
# R:  0.225860591722
# RSS: 286.530482276
# R:  -0.876803285485
# RSS: 444.155410542
# R:  -0.821879544302
# RSS: 2.0304031649e+17
# R:  0.306186235701
# RSS: 40321631.9811
# R:  -0.307787828606
# RSS: nan
# R:  nan
# Recall [Self]: mu = 0.925; std = 0.073
# RSS: 1.87565299807
# R:  -0.340240223767
# RSS: 157.364641106
# R:  -0.768184358321
# RSS: 3.07687497562e+28
# R:  -0.306186217848
# RSS: 7.90041220439e+19
# R:  -0.306186219166
# RSS: 2.03325179564e+41
# R:  -0.306186217848
# RSS: 348.012298954
# R:  -0.7842235176
# RSS: 1.02305015737e+45
# R:  -0.306186217848
# RSS: 392.078820855
# R:  -0.750832296466
# RSS: 2.60960939879e+20
# R:  -0.306186218624
# RSS: 1.01332393909e+12
# R:  -0.306197664731
# RSS: 178.248267086
# R:  -0.874786043341
# RSS: 355.028163191
# R:  -0.830724539344
# RSS: 373.482131476
# R:  -0.804747829136
# RSS: 434.048208394
# R:  -0.766186720587
# RSS: 6.45910474589e+16
# R:  -0.306186267556
# RSS: 456.310408069
# R:  -0.774706279801
# RSS: 3.26712686249e+49
# R:  -0.306186217848
# RSS: 501.222914225
# R:  -0.837720182563
# RSS: 8.04974814463e+37
# R:  -0.306186217848
# RSS: 522.28530297
# R:  -0.831495569962
# RSS: 438.120144326
# R:  -0.94697772169
# RSS: 409.868013349
# R:  -0.878386508039
# RSS: 437.996940531
# R:  -0.783143752055
# RSS: 1.60227933925e+24
# R:  -0.306186217856
# RSS: 5.42024807393e+23
# R:  -0.306186217856
# RSS: 597.425044058
# R:  -0.853423675699
# RSS: 498.538013854
# R:  -0.821973243937
# RSS: 455.724583625
# R:  -0.774907871037
# RSS: 505.34890237
# R:  -0.910014854603
# RSS: 410.971776462
# R:  -0.877900149989
# RSS: 595.456257747
# R:  -0.854612901772
# RSS: 510.517855071
# R:  -0.815933253977
# RSS: 443.836013086
# R:  -0.947456834441
# RSS: 163.658626675
# R:  -0.858035861885
# RSS: 410.414337462
# R:  -0.87809370348
# RSS: 574.68330566
# R:  -0.793865860358
# RSS: 505.659395556
# R:  -0.909900965616
# RSS: 438.285815524
# R:  -0.946915351991
# RSS: 341.930450912
# R:  -0.857662564136
# RSS: 499.249689107
# R:  -0.825877038294
# RSS: 502.059147047
# R:  -0.833353943158
# RSS: nan
# R:  nan
# invweibull : D = 0.29 ; p =0.12 ---> from same distribution
# RSS: 493.236896228
# R:  -0.84988236681
# RSS: 504.28479815
# R:  -0.830052787349
# RSS: 181.605787663
# R:  -0.172755726159
# RSS: 375.224937508
# R:  -0.904928908274
# RSS: 361.032298384
# R:  -0.818759614893
# RSS: nan
# R:  nan
# RSS: nan
# R:  nan
# RSS: 260.714392697
# R:  -0.907500803912
# RSS: 327.340129705
# R:  -0.873055790186
# RSS: 1.13761337777e+41
# R:  -0.306186217848
# RSS: 503.783816692
# R:  -0.830363475931
# RSS: 783.825256049
# R:  -0.72090914582
# RSS: 327.466315315
# R:  -0.907592914895
# RSS: 1.499271636e+45
# R:  -0.306186217848
# RSS: 5.67079422016e+17
# R:  -0.306186233321
# RSS: 29211901.6363
# R:  -0.307815303461
# RSS: 499.542257529
# R:  -0.823217426351
# RSS: 3.79340274962e+21
# R:  -0.306186218021
# RSS: 272.159085823
# R:  -0.902795203161
# RSS: 1.54289580318
# R:  nan
# RSS: inf
# R:  nan
# RSS: 1.85412188572e+26
# R:  -0.306186217848
# RSS: 517.547878128
# R:  -0.851921564922
# RSS: nan
# R:  nan
# RSS: 348.989606947
# R:  -0.911351120352
# RSS: 1.16835174183e+21
# R:  -0.306186217835
# RSS: 504.985917832
# R:  -0.843592335766
# RSS: 1.54289580318
# R:  nan
# RSS: 349.016094738
# R:  -0.911322406301
# RSS: 157.818124295
# R:  -0.544477346256
# RSS: 396.119690085
# R:  -0.811195392847
# RSS: 266.618806194
# R:  -1.0
# RSS: 231.111041637
# R:  -0.972503120401
# RSS: 1.54289580318
# R:  nan
# RSS: 236.789038855
# R:  -0.866025403784
# RSS: 181.621424962
# R:  0.0
# RSS: 3.4675909809e+61
# R:  -0.0829898981677
# RSS: 309.382173742
# R:  -0.884072691591
# RSS: 510.625929603
# R:  -0.81997768205
# RSS: 409.868013349
# R:  -0.878386508039
# RSS: 437.996940531
# R:  -0.783143752055
# RSS: nan
# R:  nan
# Jaccard [Self]: mu = 0.858; std = 0.086
# RSS: 256.276483319
# R:  -0.681577051124
# RSS: 177.894988935
# R:  -0.428622759247
# RSS: 1860.76930673
# R:  0.315842236234
# RSS: 260.703030101
# R:  -0.626483967954
# RSS: 251.201113865
# R:  -0.710807127264
# RSS: 176.425318949
# R:  -0.509753512393
# RSS: 238.878365038
# R:  -0.776515246023
# RSS: 215.107642562
# R:  -0.610626372937
# RSS: 260.441726439
# R:  -0.62673424389
# RSS: 6435329823.95
# R:  -0.306301822145
# RSS: 199.958756634
# R:  -0.562722995621
# RSS: 237.475660095
# R:  -0.587127149376
# RSS: 232.506105331
# R:  -0.6211976433
# RSS: 275.030534621
# R:  -0.939287772358
# RSS: 247.767063127
# R:  -0.64158319574
# RSS: 242.407004676
# R:  -0.747942312576
# RSS: 250.234706653
# R:  -0.715761238272
# RSS: 253.545412684
# R:  -0.70070996305
# RSS: 282.751631159
# R:  -0.592102357601
# RSS: 244.229783445
# R:  -0.621629089102
# RSS: 252.2273409
# R:  -0.671088902772
# RSS: 256.520016468
# R:  -0.682389358381
# RSS: 241.345976393
# R:  -0.753288507908
# RSS: 250.270686552
# R:  -0.71395992179
# RSS: 260.702963014
# R:  -0.626482446043
# RSS: 235.453395079
# R:  -0.879310417902
# RSS: 256.750291937
# R:  -0.683043879258
# RSS: 242.750314626
# R:  -0.745980225674
# RSS: 233.225343465
# R:  -0.945559375411
# RSS: 256.627344883
# R:  -0.682196871111
# RSS: 249.195947348
# R:  -0.675101994493
# RSS: 207.902146021
# R:  -0.853470364202
# RSS: 249.3822951
# R:  -0.665130648956
# RSS: 170.801301818
# R:  -0.47862293821
# RSS: 256.480482061
# R:  -0.682536909817
# RSS: 221.630997565
# R:  -0.678113313467
# RSS: 250.521257946
# R:  -0.9852697937
# RSS: 261.985667518
# R:  -0.693330266824
# RSS: 236.505562391
# R:  -0.630002399058
# RSS: 255.900388349
# R:  -0.688228694543
# RSS: 253.865372649
# R:  -0.699254249468
# RSS: 256.753912695
# R:  -0.683093997596
# RSS: 240.239892088
# R:  -0.742016880971
# RSS: 254.971649087
# R:  -0.694945573261
# RSS: 164.545388185
# R:  -0.439307191114
# RSS: 251.044858838
# R:  -0.69841850489
# RSS: 250.082478283
# R:  -0.611033470793
# RSS: 162.99375769
# R:  -0.61493321751
# RSS: nan
# R:  nan
# RSS: 220.719101488
# R:  -0.619243100128
# RSS: 232.692138721
# R:  -0.629571786614
# RSS: 274.061286536
# R:  -0.640997410697
# RSS: 254.839956082
# R:  -0.694325312112
# RSS: 259.546525246
# R:  -0.944181675636
# RSS: 242.735478397
# R:  -0.665616388081
# RSS: 258.76583765
# R:  -0.627194502943
# RSS: 239.184286114
# R:  -0.762247742141
# RSS: 1772424.33251
# R:  -0.311765869593
# RSS: 256.304718375
# R:  -0.687873143074
# RSS: 7.73269646216e+20
# R:  -0.306186218177
# RSS: 224.100201363
# R:  -0.619478103904
# RSS: 1.67976254596
# R:  nan
# RSS: 250.271029877
# R:  -0.713964985775
# RSS: 167.424356728
# R:  -0.833359716347
# RSS: 251.821719635
# R:  -0.706136636434
# RSS: nan
# R:  nan
# RSS: 242.952854018
# R:  -0.709440009752
# RSS: 4.35440951404e+16
# R:  -0.30618617371
# RSS: 253.361364332
# R:  -0.701522064302
# RSS: 1.67976254596
# R:  nan
# RSS: 242.951401498
# R:  -0.709370992155
# RSS: 167.364560791
# R:  -0.207479121921
# RSS: 224.091023912
# R:  -0.619473167843
# RSS: 219.378121774
# R:  -0.709180206693
# RSS: 200.243071499
# R:  -0.494704885231
# RSS: 1.67976254596
# R:  nan
# RSS: 228.085087714
# R:  -0.786606636128
# RSS: 163.323347572
# R:  -2.403257738e-16
# RSS: 1.2465579069e+58
# R:  0.0684472980888
# RSS: 234.127994775
# R:  -0.626631945382
# RSS: 214.792458799
# R:  -0.827355752135
# RSS: 256.520016468
# R:  -0.682389358381
# RSS: 241.345976393
# R:  -0.753288507908
# RSS: nan
# R:  nan

# %% [markdown]
# Pearson's R tests strength of a linear association between two variables. It is probably not the best test for this application

# %%
metrics_lst = ['Precision [COCO]','Recall [COCO]','Jaccard [COCO]',\
               'Precision [Self]','Recall [Self]','Jaccard [Self]']
FILTER_CRITERION = 0
NUM_COL = 3
NUM_ROW = 2
NUM_PLOTS = NUM_COL*NUM_ROW

fig, axs = plt.subplots(NUM_ROW,NUM_COL, figsize=(NUM_ROW*3,NUM_COL*1.5), sharex='col')
fig.suptitle("Good Worker [metric >{}]".format(FILTER_CRITERION),fontsize=16,y=1.05)
# fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()

table_data = []
data_fit_stats=[]
for i,metric in zip(range(len(metrics_lst)),metrics_lst):
    metric_value = np.array(bb_info[metric][bb_info[metric]>FILTER_CRITERION][bb_info[metric]<=1]) 
    table_data.append(basic_stat(metric_value,metric))
    ax = axs[i]
    ax.set_title(metric)
    ax.hist(metric_value,bins=30)
    ax.set_xlim(FILTER_CRITERION,1.03)
    #Testing against various distributions 
    
    for fcn_name in filter(lambda x: x not in exclude,dir(stats.distributions)[9:]):
        # Based on MLE estimate for fitting
        try:
            fcn = getattr(scipy.stats,fcn_name)
            params = fcn.fit(1-metric_value)
            histo,bins = np.histogram(1-metric_value, 30, normed=1)
            y = fcn.pdf(bins, *params)
            RSS =sum((bins-y)**2)
#            R = np.corrcoef(bins,y)[0][1]
#             print "RSS:",RSS
#             print "R: ",R
            ks_result = kolmogorov_smirnov(bins,y,fcn_name) #D-value and p-value
            data_fit_stats.append([metric,fcn_name,params,RSS,ks_result])
        except(AttributeError,NotImplementedError,TypeError):
            #function has no fitting
            print "Skipped", fcn_name
fig.tight_layout()
fig.savefig('good_worker_metric_histogram.pdf')
# Out:
# Precision [COCO]: mu = 0.869; std = 0.227
# alpha : D = 0.29 ; p =0.12 ---> from same distribution
# beta : D = 0.29 ; p =0.12 ---> from same distribution
# burr : D = 0.19 ; p =0.56 ---> from same distribution
# chi : D = 0.29 ; p =0.12 ---> from same distribution
# chi2 : D = 0.23 ; p =0.36 ---> from same distribution
# exponpow : D = 0.23 ; p =0.36 ---> from same distribution
# exponweib : D = 0.29 ; p =0.12 ---> from same distribution
# fatiguelife : D = 0.29 ; p =0.12 ---> from same distribution
# fisk : D = 0.32 ; p =0.06 ---> from same distribution
# frechet_r : D = 0.32 ; p =0.06 ---> from same distribution
# gamma : D = 0.29 ; p =0.12 ---> from same distribution
# gumbel_l : D = 0.32 ; p =0.06 ---> from same distribution
# mielke : D = 0.16 ; p =0.78 ---> from same distribution
# nakagami : D = 0.26 ; p =0.22 ---> from same distribution
# ncx2 : D = 0.23 ; p =0.36 ---> from same distribution
# pearson3 : D = 0.32 ; p =0.06 ---> from same distribution
# recipinvgauss : D = 0.29 ; p =0.12 ---> from same distribution
# weibull_min : D = 0.32 ; p =0.06 ---> from same distribution
# Recall [COCO]: mu = 0.897; std = 0.132
# betaprime : D = 0.19 ; p =0.56 ---> from same distribution
# burr : D = 0.16 ; p =0.78 ---> from same distribution
# fisk : D = 0.32 ; p =0.06 ---> from same distribution
# gausshyper : D = 0.29 ; p =0.12 ---> from same distribution
# mielke : D = 0.16 ; p =0.78 ---> from same distribution
# Jaccard [COCO]: mu = 0.789; std = 0.227
# alpha : D = 0.29 ; p =0.12 ---> from same distribution
# beta : D = 0.26 ; p =0.22 ---> from same distribution
# betaprime : D = 0.26 ; p =0.22 ---> from same distribution
# burr : D = 0.29 ; p =0.12 ---> from same distribution
# chi2 : D = 0.32 ; p =0.06 ---> from same distribution
# dgamma : D = 0.32 ; p =0.06 ---> from same distribution
# expon : D = 0.32 ; p =0.06 ---> from same distribution
# exponweib : D = 0.26 ; p =0.22 ---> from same distribution
# f : D = 0.26 ; p =0.22 ---> from same distribution
# fatiguelife : D = 0.29 ; p =0.12 ---> from same distribution
# fisk : D = 0.29 ; p =0.12 ---> from same distribution
# foldcauchy : D = 0.32 ; p =0.06 ---> from same distribution
# frechet_r : D = 0.32 ; p =0.06 ---> from same distribution
# genexpon : D = 0.32 ; p =0.06 ---> from same distribution
# genextreme : D = 0.26 ; p =0.22 ---> from same distribution
# gengamma : D = 0.26 ; p =0.22 ---> from same distribution
# genpareto : D = 0.29 ; p =0.12 ---> from same distribution
# gilbrat : D = 0.26 ; p =0.22 ---> from same distribution
# halfcauchy : D = 0.26 ; p =0.22 ---> from same distribution
# hypsecant : D = 0.32 ; p =0.06 ---> from same distribution
# invgamma : D = 0.26 ; p =0.22 ---> from same distribution
# invgauss : D = 0.26 ; p =0.22 ---> from same distribution
# invweibull : D = 0.26 ; p =0.22 ---> from same distribution
# johnsonsb : D = 0.26 ; p =0.22 ---> from same distribution
# johnsonsu : D = 0.26 ; p =0.22 ---> from same distribution
# laplace : D = 0.32 ; p =0.06 ---> from same distribution
# levy : D = 0.23 ; p =0.36 ---> from same distribution
# loglaplace : D = 0.32 ; p =0.06 ---> from same distribution
# lognorm : D = 0.26 ; p =0.22 ---> from same distribution
# lomax : D = 0.29 ; p =0.12 ---> from same distribution
# mielke : D = 0.29 ; p =0.12 ---> from same distribution
# ncf : D = 0.29 ; p =0.12 ---> from same distribution
# nct : D = 0.29 ; p =0.12 ---> from same distribution
# ncx2 : D = 0.32 ; p =0.06 ---> from same distribution
# pearson3 : D = 0.32 ; p =0.06 ---> from same distribution
# powerlognorm : D = 0.26 ; p =0.22 ---> from same distribution
# recipinvgauss : D = 0.29 ; p =0.12 ---> from same distribution
# reciprocal : D = 0.23 ; p =0.36 ---> from same distribution
# wald : D = 0.26 ; p =0.22 ---> from same distribution
# weibull_min : D = 0.32 ; p =0.06 ---> from same distribution
# Precision [Self]: mu = 0.864; std = 0.206
# beta : D = 0.29 ; p =0.12 ---> from same distribution
# betaprime : D = 0.23 ; p =0.36 ---> from same distribution
# burr : D = 0.16 ; p =0.78 ---> from same distribution
# chi : D = 0.32 ; p =0.06 ---> from same distribution
# expon : D = 0.32 ; p =0.06 ---> from same distribution
# exponpow : D = 0.26 ; p =0.22 ---> from same distribution
# exponweib : D = 0.32 ; p =0.06 ---> from same distribution
# f : D = 0.32 ; p =0.06 ---> from same distribution
# fatiguelife : D = 0.29 ; p =0.12 ---> from same distribution
# fisk : D = 0.32 ; p =0.06 ---> from same distribution
# frechet_r : D = 0.26 ; p =0.22 ---> from same distribution
# gamma : D = 0.29 ; p =0.12 ---> from same distribution
# gausshyper : D = 0.23 ; p =0.36 ---> from same distribution
# genexpon : D = 0.32 ; p =0.06 ---> from same distribution
# gengamma : D = 0.32 ; p =0.06 ---> from same distribution
# gompertz : D = 0.32 ; p =0.06 ---> from same distribution
# invgauss : D = 0.32 ; p =0.06 ---> from same distribution
# kstwobign : D = 0.32 ; p =0.06 ---> from same distribution
# lomax : D = 0.32 ; p =0.06 ---> from same distribution
# mielke : D = 0.16 ; p =0.78 ---> from same distribution
# nakagami : D = 0.29 ; p =0.12 ---> from same distribution
# ncf : D = 0.32 ; p =0.06 ---> from same distribution
# ncx2 : D = 0.29 ; p =0.12 ---> from same distribution
# powerlaw : D = 0.32 ; p =0.06 ---> from same distribution
# recipinvgauss : D = 0.29 ; p =0.12 ---> from same distribution
# reciprocal : D = 0.32 ; p =0.06 ---> from same distribution
# weibull_min : D = 0.26 ; p =0.22 ---> from same distribution
# Recall [Self]: mu = 0.901; std = 0.145
# betaprime : D = 0.19 ; p =0.56 ---> from same distribution
# bradford : D = 0.23 ; p =0.36 ---> from same distribution
# burr : D = 0.26 ; p =0.22 ---> from same distribution
# exponpow : D = 0.26 ; p =0.22 ---> from same distribution
# gamma : D = 0.26 ; p =0.22 ---> from same distribution
# gausshyper : D = 0.23 ; p =0.36 ---> from same distribution
# mielke : D = 0.19 ; p =0.56 ---> from same distribution
# powerlaw : D = 0.29 ; p =0.12 ---> from same distribution
# reciprocal : D = 0.32 ; p =0.06 ---> from same distribution
# Jaccard [Self]: mu = 0.785; std = 0.219
# alpha : D = 0.26 ; p =0.22 ---> from same distribution
# betaprime : D = 0.29 ; p =0.12 ---> from same distribution
# burr : D = 0.19 ; p =0.56 ---> from same distribution
# dgamma : D = 0.29 ; p =0.12 ---> from same distribution
# dweibull : D = 0.29 ; p =0.12 ---> from same distribution
# expon : D = 0.32 ; p =0.06 ---> from same distribution
# exponweib : D = 0.29 ; p =0.12 ---> from same distribution
# f : D = 0.29 ; p =0.12 ---> from same distribution
# fatiguelife : D = 0.32 ; p =0.06 ---> from same distribution
# fisk : D = 0.26 ; p =0.22 ---> from same distribution
# foldcauchy : D = 0.29 ; p =0.12 ---> from same distribution
# frechet_l : D = 0.23 ; p =0.36 ---> from same distribution
# gamma : D = 0.32 ; p =0.06 ---> from same distribution
# gausshyper : D = 0.29 ; p =0.12 ---> from same distribution
# genextreme : D = 0.29 ; p =0.12 ---> from same distribution
# gengamma : D = 0.29 ; p =0.12 ---> from same distribution
# genpareto : D = 0.29 ; p =0.12 ---> from same distribution
# gilbrat : D = 0.29 ; p =0.12 ---> from same distribution
# gompertz : D = 0.32 ; p =0.06 ---> from same distribution
# halfcauchy : D = 0.26 ; p =0.22 ---> from same distribution
# invgamma : D = 0.29 ; p =0.12 ---> from same distribution
# invgauss : D = 0.29 ; p =0.12 ---> from same distribution
# invweibull : D = 0.29 ; p =0.12 ---> from same distribution
# johnsonsb : D = 0.29 ; p =0.12 ---> from same distribution
# johnsonsu : D = 0.26 ; p =0.22 ---> from same distribution
# laplace : D = 0.32 ; p =0.06 ---> from same distribution
# levy : D = 0.23 ; p =0.36 ---> from same distribution
# loglaplace : D = 0.29 ; p =0.12 ---> from same distribution
# lognorm : D = 0.29 ; p =0.12 ---> from same distribution
# lomax : D = 0.32 ; p =0.06 ---> from same distribution
# mielke : D = 0.29 ; p =0.12 ---> from same distribution
# ncf : D = 0.29 ; p =0.12 ---> from same distribution
# nct : D = 0.26 ; p =0.22 ---> from same distribution
# ncx2 : D = 0.32 ; p =0.06 ---> from same distribution
# pareto : D = 0.26 ; p =0.22 ---> from same distribution
# powerlognorm : D = 0.29 ; p =0.12 ---> from same distribution
# recipinvgauss : D = 0.32 ; p =0.06 ---> from same distribution
# reciprocal : D = 0.23 ; p =0.36 ---> from same distribution
# wald : D = 0.29 ; p =0.12 ---> from same distribution
# weibull_max : D = 0.23 ; p =0.36 ---> from same distribution

# %%
import pandas as pd

# %%
df_stats_tbl = pd.DataFrame(data_fit_stats,columns=["metric","Function Name", "Parameters","RSS","KS results"])

# %%
df_stats_tbl
# Out:
#                metric    Function Name  \
# 0    Precision [COCO]            alpha
# 1    Precision [COCO]           anglit
# 2    Precision [COCO]          arcsine
# 3    Precision [COCO]             beta
# 4    Precision [COCO]        betaprime
# 5    Precision [COCO]         bradford
# 6    Precision [COCO]             burr
# 7    Precision [COCO]           cauchy
# 8    Precision [COCO]              chi
# 9    Precision [COCO]             chi2
# 10   Precision [COCO]           cosine
# 11   Precision [COCO]           dgamma
# 12   Precision [COCO]         dweibull
# 13   Precision [COCO]            expon
# 14   Precision [COCO]         exponpow
# 15   Precision [COCO]        exponweib
# 16   Precision [COCO]                f
# 17   Precision [COCO]      fatiguelife
# 18   Precision [COCO]             fisk
# 19   Precision [COCO]       foldcauchy
# 20   Precision [COCO]         foldnorm
# 21   Precision [COCO]        frechet_l
# 22   Precision [COCO]        frechet_r
# 23   Precision [COCO]            gamma
# 24   Precision [COCO]       gausshyper
# 25   Precision [COCO]         genexpon
# 26   Precision [COCO]       genextreme
# 27   Precision [COCO]         gengamma
# 28   Precision [COCO]  genhalflogistic
# 29   Precision [COCO]      genlogistic
# ..                ...              ...
# 474    Jaccard [Self]          maxwell
# 475    Jaccard [Self]           mielke
# 476    Jaccard [Self]         nakagami
# 477    Jaccard [Self]              ncf
# 478    Jaccard [Self]              nct
# 479    Jaccard [Self]             ncx2
# 480    Jaccard [Self]             norm
# 481    Jaccard [Self]           pareto
# 482    Jaccard [Self]         pearson3
# 483    Jaccard [Self]         powerlaw
# 484    Jaccard [Self]     powerlognorm
# 485    Jaccard [Self]        powernorm
# 486    Jaccard [Self]         rayleigh
# 487    Jaccard [Self]            rdist
# 488    Jaccard [Self]    recipinvgauss
# 489    Jaccard [Self]       reciprocal
# 490    Jaccard [Self]             rice
# 491    Jaccard [Self]     semicircular
# 492    Jaccard [Self]                t
# 493    Jaccard [Self]           triang
# 494    Jaccard [Self]       truncexpon
# 495    Jaccard [Self]        truncnorm
# 496    Jaccard [Self]      tukeylambda
# 497    Jaccard [Self]          uniform
# 498    Jaccard [Self]         vonmises
# 499    Jaccard [Self]    vonmises_line
# 500    Jaccard [Self]             wald
# 501    Jaccard [Self]      weibull_max
# 502    Jaccard [Self]      weibull_min
# 503    Jaccard [Self]       wrapcauchy
#
#                                             Parameters           RSS  \
# 0    (3.44601427617e-13, 0.000210696565, 0.25166628...  2.605158e+01
# 1                      (0.14554611421, 0.388370882812)  5.736937e+01
# 2                 (-6.89918447858e-25, 0.461778164357)  3.180307e+23
# 3    (0.637502104133, 72.5709701795, -4.75857597689...  8.982414e+18
# 4    (0.944082798766, 2.69444095114, -2.00652653706...  9.005157e+04
# 5    (2.22273747481, -3.41383256103e-08, 0.44992120...  8.365840e+01
# 6    (1.251274532, 0.250782381153, -3.00236472075e-...  3.872603e+43
# 7                   (0.0429343168628, 0.0345932766061)  1.402426e+02
# 8    (0.431687417238, -9.19762794913e-30, 0.3475127...  4.150633e+32
# 9    (0.882605096367, -2.5887240618e-30, 0.31644708...  4.270052e+32
# 10                    (0.167454544723, 0.192567584117)  3.039091e+01
# 11     (0.532032412007, 0.03617641086, 0.186254079051)  1.575395e+02
# 12   (0.678732608092, 0.036388985813, 0.0777859277351)  1.568812e+02
# 13                 (-2.04839426838e-09, 0.13117953855)  1.485646e+02
# 14   (0.399878603155, -1.63634144783e-30, 0.4143235...  1.821692e+35
# 15   (0.919630485916, 0.809625145505, -9.8169973406...           inf
# 16   (2.51982791143, 3.16501284302, -0.000179696377...  1.505191e+02
# 17   (1.51586816926, -0.00325765252706, 0.064205186...  9.662914e+01
# 18   (0.488054832861, -7.98742459215e-31, 1.0146062...  1.539660e+30
# 19   (0.304858277683, -1.11234341207e-10, 0.0500471...  2.549925e+02
# 20   (0.07220020285, -1.07899965753e-09, 0.26164189...  6.712036e+01
# 21     (1.00134793083, 0.449921389776, 0.210563822625)  6.482392e+01
# 22   (0.699384059856, -1.06226644904e-28, 0.0993629...  8.143330e+17
# 23   (0.671005160849, -8.57025084408e-31, 0.4479886...  9.849469e+19
# 24   (0.756299898832, 2.6184330228, 1.06064112557, ...  2.721644e+14
# 25   (2.75435325332, 0.89720460562, 4.56924674009e-...  1.485478e+02
# 26   (-0.877511285092, 0.0324408902704, 0.038117462...  1.430814e+02
# 27   (7.50479963829, 0.264269284094, -0.00047635786...  1.574204e+02
# 28   (0.132271114262, -1.14914099273e-08, 0.0653280...  2.073901e+02
# 29   (1347.56183473, -0.602846895569, 0.0918736059243)  8.061401e+01
# ..                                                 ...           ...
# 474                   (-0.205876494417, 0.27395976653)  4.113073e+01
# 475  (7.05860590755, 2.14635629336, -0.052072833071...  7.946982e+01
# 476  (0.358797439632, -6.69980621316e-28, 0.3163114...  3.620766e+15
# 477  (14.0511651877, 6.08524306439, 3.2331855861, -...  7.555913e+01
# 478  (2.05460109111, 3.67014960064, -0.041239341029...  8.036112e+01
# 479  (2.30349456375, 0.000448303278959, 0.020090832...  7.194951e+01
# 480                   (0.215051889599, 0.219079111841)  3.252465e+01
# 481  (0.769813853709, -0.0463974761814, 0.066526665...  1.107724e+02
# 482    (1.76586588635, 0.215041347588, 0.191540010274)  6.347440e+01
# 483  (0.473505868276, -6.54631231652e-27, 1.0067294...  8.305016e+26
# 484  (0.206435705843, 0.403841169247, -0.0385282686...  7.318370e+01
# 485  (1.4316240987e-05, -0.0986374772816, 0.0010242...           NaN
# 486                 (-0.0985329831647, 0.270504732037)  4.417653e+01
# 487   (0.880397987422, 0.520806801454, 0.520806801454)  4.824584e+16
# 488  (0.842141484104, -0.0224639801646, 0.108578292...  6.617403e+01
# 489  (0.0250131803338, 1.40436000678, 0.00236104801...  9.533958e+01
# 490  (0.000222572796055, -0.0985437425642, 0.270497...  4.417850e+01
# 491                   (0.428895238283, 0.572280250496)  1.191303e+01
# 492   (1.46095240605, 0.130932565197, 0.0764284932836)  7.414848e+01
# 493  (2.46973579868e-08, -2.6874157337e-08, 1.01750...  3.142561e+01
# 494  (1.34135046823, -1.34037233403e-08, 0.74547991...  2.271191e+01
# 495                              (1.05, 1.0, 0.0, 1.0)  1.050450e+01
# 496              (1.0, 0.215051889599, 0.379456152585)  2.831772e+01
# 497               (-1.33110874835e-06, 0.999955073974)  1.050745e+01
# 498    (1.66426074083, 0.137410929371, 0.105993306087)  1.278070e+02
# 499    (2.54791871566, 0.180502237437, 0.260838265443)  4.278789e+01
# 500                 (-0.0232695226106, 0.253130316075)  6.876092e+01
# 501   (0.477492610206, 0.999949810938, 0.173376304806)  5.720960e+16
# 502  (1.07810381684, -0.000459259929743, 0.22221274...  6.703556e+01
# 503                                    (1.0, 0.0, 1.0)           NaN
#
#                               KS results
# 0       (0.290322580645, 0.120027916029)
# 1    (0.516129032258, 0.000275423343949)
# 2    (0.516129032258, 0.000275423343949)
# 3       (0.290322580645, 0.120027916029)
# 4      (0.387096774194, 0.0134648311178)
# 5    (0.516129032258, 0.000275423343949)
# 6       (0.193548387097, 0.559453127044)
# 7    (0.548387096774, 8.75568129997e-05)
# 8       (0.290322580645, 0.120027916029)
# 9       (0.225806451613, 0.362545744904)
# 10     (0.41935483871, 0.00565128742091)
# 11     (0.41935483871, 0.00565128742091)
# 12    (0.451612903226, 0.00221273536199)
# 13     (0.354838709677, 0.0299287745248)
# 14      (0.225806451613, 0.362545744904)
# 15      (0.290322580645, 0.120027916029)
# 16     (0.387096774194, 0.0134648311178)
# 17      (0.290322580645, 0.120027916029)
# 18     (0.322580645161, 0.0620586707579)
# 19     (0.41935483871, 0.00565128742091)
# 20     (0.387096774194, 0.0134648311178)
# 21   (0.516129032258, 0.000275423343949)
# 22     (0.322580645161, 0.0620586707579)
# 23      (0.290322580645, 0.120027916029)
# 24   (0.548387096774, 8.75568129997e-05)
# 25     (0.354838709677, 0.0299287745248)
# 26     (0.41935483871, 0.00565128742091)
# 27     (0.354838709677, 0.0299287745248)
# 28   (0.645161290323, 1.85426497193e-06)
# 29     (0.41935483871, 0.00565128742091)
# ..                                   ...
# 474   (0.451612903226, 0.00221273536199)
# 475     (0.290322580645, 0.120027916029)
# 476    (0.387096774194, 0.0134648311178)
# 477     (0.290322580645, 0.120027916029)
# 478       (0.258064516129, 0.2163815599)
# 479    (0.322580645161, 0.0620586707579)
# 480   (0.451612903226, 0.00221273536199)
# 481       (0.258064516129, 0.2163815599)
# 482    (0.354838709677, 0.0299287745248)
# 483  (0.483870967742, 0.000808252873678)
# 484     (0.290322580645, 0.120027916029)
# 485             (1.0, 6.41339762992e-15)
# 486   (0.451612903226, 0.00221273536199)
# 487  (0.548387096774, 8.75568129997e-05)
# 488    (0.322580645161, 0.0620586707579)
# 489     (0.225806451613, 0.362545744904)
# 490   (0.451612903226, 0.00221273536199)
# 491   (0.58064516129, 2.59665859276e-05)
# 492    (0.354838709677, 0.0299287745248)
# 493  (0.483870967742, 0.000808252873678)
# 494  (0.483870967742, 0.000808252873678)
# 495  (0.967741935484, 5.33456538599e-14)
# 496   (0.58064516129, 2.59665859276e-05)
# 497             (1.0, 6.41339762992e-15)
# 498   (0.58064516129, 2.59665859276e-05)
# 499    (0.387096774194, 0.0134648311178)
# 500     (0.290322580645, 0.120027916029)
# 501     (0.225806451613, 0.362545744904)
# 502    (0.354838709677, 0.0299287745248)
# 503             (1.0, 6.41339762992e-15)
#
# [504 rows x 5 columns]

# %%
df_stats_tbl.to_csv("metric_distr_fitting.csv")

# %% [markdown]
# - Good Worker's Measures (filtered precision, recall >0.6)
# - see if timing correlated with precision recall
# - average time for a task for worker and good worker
# - majority vote score statistics
