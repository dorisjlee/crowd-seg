# %%
cd TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from TileEM_plot_toolbox import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img_info,object_tbl,bb_info,hit_info = load_info()

# %%
objid=14
bb_objects = bb_info[bb_info["object_id"]==objid]
bb_objects =  bb_objects[bb_objects.worker_id!=3]

# %%
obj_x_locs = [process_raw_locs([x,y])[0] for x,y in zip(bb_objects["x_locs"],bb_objects["y_locs"])]
obj_y_locs = [process_raw_locs([x,y])[1] for x,y in zip(bb_objects["x_locs"],bb_objects["y_locs"])]

# %%
xylocs = [list(zip(*process_raw_locs([x,y]))) for x,y in zip(bb_objects["x_locs"],bb_objects["y_locs"])]

# %%
polygon_lst = []
for xyloc in xylocs:
    polygon_lst.append(Polygon(xyloc).buffer(0))

# %%
polygon = Polygon(xylocs[0])
polygon2 = Polygon(xylocs[1])

# %%
polygon2

# %%
polygon

# %%
intersection = polygon2.intersection(polygon)

# %%
nonoverlap = (polygon.symmetric_difference(polygon2)).difference(polygon2)

# %%
nonoverlap

# %%
type(nonoverlap)
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %%
# multipol1 and multipol2 are my shapely MultiPolygons
from shapely.ops import cascaded_union
from itertools import combinations
from shapely.geometry import Polygon,MultiPolygon

outmulti = []
for pol in multipoly1:
    for pol2 in multipoly2:
        if pol.intersects(pol2)==True:
            # If they intersect, create a new polygon that is
            # essentially pol minus the intersection
            nonoverlap = (pol.symmetric_difference(pol2)).difference(pol2)
            outmulti.append(nonoverlap)

        else:
            # Otherwise, just keep the initial polygon as it is.
            outmulti.append(pol)

finalpol = MultiPolygon(outmulti)

# %%
polygon

# %%
from shapely.geometry import MultiPolygon

# %%
Ji_polygons = MultiPolygon(polygon_lst)
Ji_polygons_buffered = Ji_polygons.buffer(0.001)

# %%
import shapely

# %%
obj_x_locs = [process_raw_locs([x,y])[0] for x,y in zip(bb_objects["x_locs"],bb_objects["y_locs"])]
obj_y_locs = [process_raw_locs([x,y])[1] for x,y in zip(bb_objects["x_locs"],bb_objects["y_locs"])]

# %%
from shapely.geometry import LineString
layer = polygon_lst
rings = [LineString(list(pol.exterior.coords)) for pol in layer]
from shapely.ops import unary_union, polygonize

# %%
polygon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-cf6c1486e55d> in <module>()
# ----> 1 polygon
#
# NameError: name 'polygon' is not defined

# %%
union = unary_union(rings)
# Out:
# ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (465.455 214.909, 465.375 215.625) and LINESTRING (465.455 214.909, 465.25 215.25) at 465.45454545454544 214.90909090909091
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-aad23a96c2e3> in <module>()
# ----> 1 union = unary_union(rings)
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/shapely/ops.pyc in unary_union(self, geoms)
#     148             subs[i] = g._geom
#     149         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 150         return geom_factory(lgeos.methods['unary_union'](collection))
#     151
#     152 operator = CollectionOperator()
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/shapely/geometry/base.pyc in geom_factory(g, parent)
#      74     # Abstract geometry factory for use with topological methods below
#      75     if not g:
# ---> 76         raise ValueError("No Shapely geometry can be created from null value")
#      77     ob = BaseGeometry()
#      78     geom_type = geometry_type_name(g)
#
# ValueError: No Shapely geometry can be created from null value

# %%
result = [geom for geom in polygonize(union)]

# %%
schema=layer.schema.copy()
schema['properties']['area'] = 'float:10.2'
# for index, pol in enumerate(result):
#    #c.write({'geometry': mapping(pol),'properties': {'id': index, 'area': pol.area}})

# %%
union =unary_union(polygon_lst)
# Out:
# ERROR:shapely.geos:TopologyException: Input geom 1 is invalid: Self-intersection at or near point 152 274 at 152 274
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-80830c5806be> in <module>()
# ----> 1 union =unary_union(polygon_lst)
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/shapely/ops.pyc in unary_union(self, geoms)
#     148             subs[i] = g._geom
#     149         collection = lgeos.GEOSGeom_createCollection(6, subs, L)
# --> 150         return geom_factory(lgeos.methods['unary_union'](collection))
#     151
#     152 operator = CollectionOperator()
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/shapely/geometry/base.pyc in geom_factory(g, parent)
#      74     # Abstract geometry factory for use with topological methods below
#      75     if not g:
# ---> 76         raise ValueError("No Shapely geometry can be created from null value")
#      77     ob = BaseGeometry()
#      78     geom_type = geometry_type_name(g)
#
# ValueError: No Shapely geometry can be created from null value

# %%
rings = [LineString(pol.exterior.coords) for pol in circles]
union = unary_union(rings)
result = [geom for geom in polygonize(union)]

# %%
circles = polygon_lst

# %%
import itertools
for  i,j in itertools.combinations(enumerate(circles), 2):
    if i[1].intersects(j[1]):
        print "polygons", i[0],j[0] 


for  i,j in itertools.permutations(enumerate(circles), 2):
    if i[1].intersects(j[1]):
        print "polygons", i[0],j[0]
# Out:
# polygons 0 1
# polygons 0 2
# polygons 0 3
# polygons 0 4
# polygons 0 5
# polygons 0 6
# polygons 0 7
# polygons 0 8
# polygons 0 9
# polygons 0 10
# polygons 0 11
# polygons 0 12
# polygons 0 13
# polygons 0 14
# polygons 0 15
# polygons 0 16
# polygons 0 17
# polygons 0 18
# polygons 0 19
# polygons 0 20
# polygons 0 21
# polygons 0 22
# polygons 0 23
# polygons 0 24
# polygons 0 25
# polygons 0 26
# polygons 0 27
# polygons 0 28
# polygons 0 29
# polygons 0 30
# polygons 0 31
# polygons 0 32
# polygons 0 33
# polygons 0 34
# polygons 0 35
# polygons 0 36
# polygons 0 37
# polygons 0 38
# polygons 0 39
# polygons 0 40
# polygons 1 2
# polygons 1 3
# polygons 1 4
# polygons 1 5
# polygons 1 6
# polygons 1 7
# polygons 1 8
# polygons 1 9
# polygons 1 10
# polygons 1 11
# polygons 1 12
# polygons 1 13
# polygons 1 14
# polygons 1 15
# polygons 1 16
# polygons 1 17
# polygons 1 18
# polygons 1 19
# polygons 1 20
# polygons 1 21
# polygons 1 22
# polygons 1 23
# polygons 1 24
# polygons 1 25
# polygons 1 26
# polygons 1 27
# polygons 1 28
# polygons 1 29
# polygons 1 30
# polygons 1 31
# polygons 1 32
# polygons 1 33
# polygons 1 34
# polygons 1 35
# polygons 1 36
# polygons 1 37
# polygons 1 38
# polygons 1 39
# polygons 1 40
# polygons 2 3
# polygons 2 4
# polygons 2 5
# polygons 2 6
# polygons 2 7
# polygons 2 8
# polygons 2 9
# polygons 2 10
# polygons 2 11
# polygons 2 12
# polygons 2 13
# polygons 2 14
# polygons 2 15
# polygons 2 16
# polygons 2 17
# polygons 2 18
# polygons 2 19
# polygons 2 20
# polygons 2 21
# polygons 2 22
# polygons 2 23
# polygons 2 24
# polygons 2 25
# polygons 2 26
# polygons 2 27
# polygons 2 28
# polygons 2 29
# polygons 2 30
# polygons 2 31
# polygons 2 32
# polygons 2 33
# polygons 2 34
# polygons 2 35
# polygons 2 36
# polygons 2 37
# polygons 2 38
# polygons 2 39
# polygons 2 40
# polygons 3 4
# polygons 3 5
# polygons 3 6
# polygons 3 7
# polygons 3 8
# polygons 3 9
# polygons 3 10
# polygons 3 11
# polygons 3 12
# polygons 3 13
# polygons 3 14
# polygons 3 15
# polygons 3 16
# polygons 3 17
# polygons 3 18
# polygons 3 19
# polygons 3 20
# polygons 3 21
# polygons 3 22
# polygons 3 23
# polygons 3 24
# polygons 3 25
# polygons 3 26
# polygons 3 27
# polygons 3 28
# polygons 3 29
# polygons 3 30
# polygons 3 31
# polygons 3 32
# polygons 3 33
# polygons 3 34
# polygons 3 35
# polygons 3 36
# polygons 3 37
# polygons 3 38
# polygons 3 39
# polygons 3 40
# polygons 4 5
# polygons 4 6
# polygons 4 7
# polygons 4 8
# polygons 4 9
# polygons 4 10
# polygons 4 11
# polygons 4 12
# polygons 4 13
# polygons 4 14
# polygons 4 15
# polygons 4 16
# polygons 4 17
# polygons 4 18
# polygons 4 19
# polygons 4 20
# polygons 4 21
# polygons 4 22
# polygons 4 23
# polygons 4 24
# polygons 4 25
# polygons 4 26
# polygons 4 27
# polygons 4 28
# polygons 4 29
# polygons 4 30
# polygons 4 31
# polygons 4 32
# polygons 4 33
# polygons 4 34
# polygons 4 35
# polygons 4 36
# polygons 4 37
# polygons 4 38
# polygons 4 39
# polygons 4 40
# polygons 5 6
# polygons 5 7
# polygons 5 8
# polygons 5 9
# polygons 5 10
# polygons 5 11
# polygons 5 12
# polygons 5 13
# polygons 5 14
# polygons 5 15
# polygons 5 16
# polygons 5 17
# polygons 5 18
# polygons 5 19
# polygons 5 20
# polygons 5 21
# polygons 5 22
# polygons 5 23
# polygons 5 24
# polygons 5 25
# polygons 5 26
# polygons 5 27
# polygons 5 28
# polygons 5 29
# polygons 5 30
# polygons 5 31
# polygons 5 32
# polygons 5 33
# polygons 5 34
# polygons 5 35
# polygons 5 36
# polygons 5 37
# polygons 5 38
# polygons 5 39
# polygons 5 40
# polygons 6 7
# polygons 6 8
# polygons 6 9
# polygons 6 10
# polygons 6 11
# polygons 6 12
# polygons 6 13
# polygons 6 14
# polygons 6 15
# polygons 6 16
# polygons 6 17
# polygons 6 18
# polygons 6 19
# polygons 6 20
# polygons 6 21
# polygons 6 22
# polygons 6 23
# polygons 6 24
# polygons 6 25
# polygons 6 26
# polygons 6 27
# polygons 6 28
# polygons 6 29
# polygons 6 30
# polygons 6 31
# polygons 6 32
# polygons 6 33
# polygons 6 34
# polygons 6 35
# polygons 6 36
# polygons 6 37
# polygons 6 38
# polygons 6 39
# polygons 6 40
# polygons 7 8
# polygons 7 9
# polygons 7 10
# polygons 7 11
# polygons 7 12
# polygons 7 13
# polygons 7 14
# polygons 7 15
# polygons 7 16
# polygons 7 17
# polygons 7 18
# polygons 7 19
# polygons 7 20
# polygons 7 21
# polygons 7 22
# polygons 7 23
# polygons 7 24
# polygons 7 25
# polygons 7 26
# polygons 7 27
# polygons 7 28
# polygons 7 29
# polygons 7 30
# polygons 7 31
# polygons 7 32
# polygons 7 33
# polygons 7 34
# polygons 7 35
# polygons 7 36
# polygons 7 37
# polygons 7 38
# polygons 7 39
# polygons 7 40
# polygons 8 9
# polygons 8 10
# polygons 8 11
# polygons 8 12
# polygons 8 13
# polygons 8 14
# polygons 8 15
# polygons 8 16
# polygons 8 17
# polygons 8 18
# polygons 8 19
# polygons 8 20
# polygons 8 21
# polygons 8 22
# polygons 8 23
# polygons 8 24
# polygons 8 25
# polygons 8 26
# polygons 8 27
# polygons 8 28
# polygons 8 29
# polygons 8 30
# polygons 8 31
# polygons 8 32
# polygons 8 33
# polygons 8 34
# polygons 8 35
# polygons 8 36
# polygons 8 37
# polygons 8 38
# polygons 8 39
# polygons 8 40
# polygons 9 10
# polygons 9 11
# polygons 9 12
# polygons 9 13
# polygons 9 14
# polygons 9 15
# polygons 9 16
# polygons 9 17
# polygons 9 18
# polygons 9 19
# polygons 9 20
# polygons 9 21
# polygons 9 22
# polygons 9 23
# polygons 9 24
# polygons 9 25
# polygons 9 26
# polygons 9 27
# polygons 9 28
# polygons 9 29
# polygons 9 30
# polygons 9 31
# polygons 9 32
# polygons 9 33
# polygons 9 34
# polygons 9 35
# polygons 9 36
# polygons 9 37
# polygons 9 38
# polygons 9 39
# polygons 9 40
# polygons 10 11
# polygons 10 12
# polygons 10 13
# polygons 10 14
# polygons 10 15
# polygons 10 16
# polygons 10 17
# polygons 10 18
# polygons 10 19
# polygons 10 20
# polygons 10 21
# polygons 10 22
# polygons 10 23
# polygons 10 24
# polygons 10 25
# polygons 10 26
# polygons 10 27
# polygons 10 28
# polygons 10 29
# polygons 10 30
# polygons 10 31
# polygons 10 32
# polygons 10 33
# polygons 10 34
# polygons 10 35
# polygons 10 36
# polygons 10 37
# polygons 10 38
# polygons 10 39
# polygons 10 40
# polygons 11 12
# polygons 11 13
# polygons 11 14
# polygons 11 15
# polygons 11 16
# polygons 11 17
# polygons 11 18
# polygons 11 19
# polygons 11 20
# polygons 11 21
# polygons 11 22
# polygons 11 23
# polygons 11 24
# polygons 11 25
# polygons 11 26
# polygons 11 27
# polygons 11 28
# polygons 11 29
# polygons 11 30
# polygons 11 31
# polygons 11 32
# polygons 11 33
# polygons 11 34
# polygons 11 35
# polygons 11 36
# polygons 11 37
# polygons 11 38
# polygons 11 39
# polygons 11 40
# polygons 12 13
# polygons 12 14
# polygons 12 15
# polygons 12 16
# polygons 12 17
# polygons 12 18
# polygons 12 19
# polygons 12 20
# polygons 12 21
# polygons 12 22
# polygons 12 23
# polygons 12 24
# polygons 12 25
# polygons 12 26
# polygons 12 27
# polygons 12 28
# polygons 12 29
# polygons 12 30
# polygons 12 31
# polygons 12 32
# polygons 12 33
# polygons 12 34
# polygons 12 35
# polygons 12 36
# polygons 12 37
# polygons 12 38
# polygons 12 39
# polygons 12 40
# polygons 13 14
# polygons 13 15
# polygons 13 16
# polygons 13 17
# polygons 13 18
# polygons 13 19
# polygons 13 20
# polygons 13 21
# polygons 13 22
# polygons 13 23
# polygons 13 24
# polygons 13 25
# polygons 13 26
# polygons 13 27
# polygons 13 28
# polygons 13 29
# polygons 13 30
# polygons 13 31
# polygons 13 32
# polygons 13 33
# polygons 13 34
# polygons 13 35
# polygons 13 36
# polygons 13 37
# polygons 13 38
# polygons 13 39
# polygons 13 40
# polygons 14 15
# polygons 14 16
# polygons 14 17
# polygons 14 18
# polygons 14 19
# polygons 14 20
# polygons 14 21
# polygons 14 22
# polygons 14 23
# polygons 14 24
# polygons 14 25
# polygons 14 26
# polygons 14 27
# polygons 14 28
# polygons 14 29
# polygons 14 30
# polygons 14 31
# polygons 14 32
# polygons 14 33
# polygons 14 34
# polygons 14 35
# polygons 14 36
# polygons 14 37
# polygons 14 38
# polygons 14 39
# polygons 14 40
# polygons 15 16
# polygons 15 17
# polygons 15 18
# polygons 15 19
# polygons 15 20
# polygons 15 21
# polygons 15 22
# polygons 15 23
# polygons 15 24
# polygons 15 25
# polygons 15 26
# polygons 15 27
# polygons 15 28
# polygons 15 29
# polygons 15 30
# polygons 15 31
# polygons 15 32
# polygons 15 33
# polygons 15 34
# polygons 15 35
# polygons 15 36
# polygons 15 37
# polygons 15 38
# polygons 15 39
# polygons 15 40
# polygons 16 17
# polygons 16 18
# polygons 16 19
# polygons 16 20
# polygons 16 21
# polygons 16 22
# polygons 16 23
# polygons 16 24
# polygons 16 25
# polygons 16 26
# polygons 16 27
# polygons 16 28
# polygons 16 29
# polygons 16 30
# polygons 16 31
# polygons 16 32
# polygons 16 33
# polygons 16 34
# polygons 16 35
# polygons 16 36
# polygons 16 37
# polygons 16 38
# polygons 16 39
# polygons 16 40
# polygons 17 18
# polygons 17 19
# polygons 17 20
# polygons 17 21
# polygons 17 22
# polygons 17 23
# polygons 17 24
# polygons 17 25
# polygons 17 26
# polygons 17 27
# polygons 17 28
# polygons 17 29
# polygons 17 30
# polygons 17 31
# polygons 17 32
# polygons 17 33
# polygons 17 34
# polygons 17 35
# polygons 17 36
# polygons 17 37
# polygons 17 38
# polygons 17 39
# polygons 17 40
# polygons 18 19
# polygons 18 20
# polygons 18 21
# polygons 18 22
# polygons 18 23
# polygons 18 24
# polygons 18 25
# polygons 18 26
# polygons 18 27
# polygons 18 28
# polygons 18 29
# polygons 18 30
# polygons 18 31
# polygons 18 32
# polygons 18 33
# polygons 18 34
# polygons 18 35
# polygons 18 36
# polygons 18 37
# polygons 18 38
# polygons 18 39
# polygons 18 40
# polygons 19 20
# polygons 19 21
# polygons 19 22
# polygons 19 23
# polygons 19 24
# polygons 19 25
# polygons 19 26
# polygons 19 27
# polygons 19 28
# polygons 19 29
# polygons 19 30
# polygons 19 31
# polygons 19 32
# polygons 19 33
# polygons 19 34
# polygons 19 35
# polygons 19 36
# polygons 19 37
# polygons 19 38
# polygons 19 39
# polygons 19 40
# polygons 20 21
# polygons 20 22
# polygons 20 23
# polygons 20 24
# polygons 20 25
# polygons 20 26
# polygons 20 27
# polygons 20 28
# polygons 20 29
# polygons 20 30
# polygons 20 31
# polygons 20 32
# polygons 20 33
# polygons 20 34
# polygons 20 35
# polygons 20 36
# polygons 20 37
# polygons 20 38
# polygons 20 39
# polygons 20 40
# polygons 21 22
# polygons 21 23
# polygons 21 24
# polygons 21 25
# polygons 21 26
# polygons 21 27
# polygons 21 28
# polygons 21 29
# polygons 21 30
# polygons 21 31
# polygons 21 32
# polygons 21 33
# polygons 21 34
# polygons 21 35
# polygons 21 36
# polygons 21 37
# polygons 21 38
# polygons 21 39
# polygons 21 40
# polygons 22 23
# polygons 22 24
# polygons 22 25
# polygons 22 26
# polygons 22 27
# polygons 22 28
# polygons 22 29
# polygons 22 30
# polygons 22 31
# polygons 22 32
# polygons 22 33
# polygons 22 34
# polygons 22 35
# polygons 22 36
# polygons 22 37
# polygons 22 38
# polygons 22 39
# polygons 22 40
# polygons 23 24
# polygons 23 25
# polygons 23 26
# polygons 23 27
# polygons 23 28
# polygons 23 29
# polygons 23 30
# polygons 23 31
# polygons 23 32
# polygons 23 33
# polygons 23 34
# polygons 23 35
# polygons 23 36
# polygons 23 37
# polygons 23 38
# polygons 23 39
# polygons 23 40
# polygons 24 25
# polygons 24 26
# polygons 24 27
# polygons 24 28
# polygons 24 29
# polygons 24 30
# polygons 24 31
# polygons 24 32
# polygons 24 33
# polygons 24 34
# polygons 24 35
# polygons 24 36
# polygons 24 37
# polygons 24 38
# polygons 24 39
# polygons 24 40
# polygons 25 26
# polygons 25 27
# polygons 25 28
# polygons 25 29
# polygons 25 30
# polygons 25 31
# polygons 25 32
# polygons 25 33
# polygons 25 34
# polygons 25 35
# polygons 25 36
# polygons 25 37
# polygons 25 38
# polygons 25 39
# polygons 25 40
# polygons 26 27
# polygons 26 28
# polygons 26 29
# polygons 26 30
# polygons 26 31
# polygons 26 32
# polygons 26 33
# polygons 26 34
# polygons 26 35
# polygons 26 36
# polygons 26 37
# polygons 26 38
# polygons 26 39
# polygons 26 40
# polygons 27 28
# polygons 27 29
# polygons 27 30
# polygons 27 31
# polygons 27 32
# polygons 27 33
# polygons 27 34
# polygons 27 35
# polygons 27 36
# polygons 27 37
# polygons 27 38
# polygons 27 39
# polygons 27 40
# polygons 28 29
# polygons 28 30
# polygons 28 31
# polygons 28 32
# polygons 28 33
# polygons 28 34
# polygons 28 35
# polygons 28 36
# polygons 28 37
# polygons 28 38
# polygons 28 39
# polygons 28 40
# polygons 29 30
# polygons 29 31
# polygons 29 32
# polygons 29 33
# polygons 29 34
# polygons 29 35
# polygons 29 36
# polygons 29 37
# polygons 29 38
# polygons 29 39
# polygons 29 40
# polygons 30 31
# polygons 30 32
# polygons 30 33
# polygons 30 34
# polygons 30 35
# polygons 30 36
# polygons 30 37
# polygons 30 38
# polygons 30 39
# polygons 30 40
# polygons 31 32
# polygons 31 33
# polygons 31 34
# polygons 31 35
# polygons 31 36
# polygons 31 37
# polygons 31 38
# polygons 31 39
# polygons 31 40
# polygons 32 33
# polygons 32 34
# polygons 32 35
# polygons 32 36
# polygons 32 37
# polygons 32 38
# polygons 32 39
# polygons 32 40
# polygons 33 34
# polygons 33 35
# polygons 33 36
# polygons 33 37
# polygons 33 38
# polygons 33 39
# polygons 33 40
# polygons 34 35
# polygons 34 36
# polygons 34 37
# polygons 34 38
# polygons 34 39
# polygons 34 40
# polygons 35 36
# polygons 35 37
# polygons 35 38
# polygons 35 39
# polygons 35 40
# polygons 36 37
# polygons 36 38
# polygons 36 39
# polygons 36 40
# polygons 37 38
# polygons 37 39
# polygons 37 40
# polygons 38 39
# polygons 38 40
# polygons 39 40
# polygons 0 1
# polygons 0 2
# polygons 0 3
# polygons 0 4
# polygons 0 5
# polygons 0 6
# polygons 0 7
# polygons 0 8
# polygons 0 9
# polygons 0 10
# polygons 0 11
# polygons 0 12
# polygons 0 13
# polygons 0 14
# polygons 0 15
# polygons 0 16
# polygons 0 17
# polygons 0 18
# polygons 0 19
# polygons 0 20
# polygons 0 21
# polygons 0 22
# polygons 0 23
# polygons 0 24
# polygons 0 25
# polygons 0 26
# polygons 0 27
# polygons 0 28
# polygons 0 29
# polygons 0 30
# polygons 0 31
# polygons 0 32
# polygons 0 33
# polygons 0 34
# polygons 0 35
# polygons 0 36
# polygons 0 37
# polygons 0 38
# polygons 0 39
# polygons 0 40
# polygons 1 0
# polygons 1 2
# polygons 1 3
# polygons 1 4
# polygons 1 5
# polygons 1 6
# polygons 1 7
# polygons 1 8
# polygons 1 9
# polygons 1 10
# polygons 1 11
# polygons 1 12
# polygons 1 13
# polygons 1 14
# polygons 1 15
# polygons 1 16
# polygons 1 17
# polygons 1 18
# polygons 1 19
# polygons 1 20
# polygons 1 21
# polygons 1 22
# polygons 1 23
# polygons 1 24
# polygons 1 25
# polygons 1 26
# polygons 1 27
# polygons 1 28
# polygons 1 29
# polygons 1 30
# polygons 1 31
# polygons 1 32
# polygons 1 33
# polygons 1 34
# polygons 1 35
# polygons 1 36
# polygons 1 37
# polygons 1 38
# polygons 1 39
# polygons 1 40
# polygons 2 0
# polygons 2 1
# polygons 2 3
# polygons 2 4
# polygons 2 5
# polygons 2 6
# polygons 2 7
# polygons 2 8
# polygons 2 9
# polygons 2 10
# polygons 2 11
# polygons 2 12
# polygons 2 13
# polygons 2 14
# polygons 2 15
# polygons 2 16
# polygons 2 17
# polygons 2 18
# polygons 2 19
# polygons 2 20
# polygons 2 21
# polygons 2 22
# polygons 2 23
# polygons 2 24
# polygons 2 25
# polygons 2 26
# polygons 2 27
# polygons 2 28
# polygons 2 29
# polygons 2 30
# polygons 2 31
# polygons 2 32
# polygons 2 33
# polygons 2 34
# polygons 2 35
# polygons 2 36
# polygons 2 37
# polygons 2 38
# polygons 2 39
# polygons 2 40
# polygons 3 0
# polygons 3 1
# polygons 3 2
# polygons 3 4
# polygons 3 5
# polygons 3 6
# polygons 3 7
# polygons 3 8
# polygons 3 9
# polygons 3 10
# polygons 3 11
# polygons 3 12
# polygons 3 13
# polygons 3 14
# polygons 3 15
# polygons 3 16
# polygons 3 17
# polygons 3 18
# polygons 3 19
# polygons 3 20
# polygons 3 21
# polygons 3 22
# polygons 3 23
# polygons 3 24
# polygons 3 25
# polygons 3 26
# polygons 3 27
# polygons 3 28
# polygons 3 29
# polygons 3 30
# polygons 3 31
# polygons 3 32
# polygons 3 33
# polygons 3 34
# polygons 3 35
# polygons 3 36
# polygons 3 37
# polygons 3 38
# polygons 3 39
# polygons 3 40
# polygons 4 0
# polygons 4 1
# polygons 4 2
# polygons 4 3
# polygons 4 5
# polygons 4 6
# polygons 4 7
# polygons 4 8
# polygons 4 9
# polygons 4 10
# polygons 4 11
# polygons 4 12
# polygons 4 13
# polygons 4 14
# polygons 4 15
# polygons 4 16
# polygons 4 17
# polygons 4 18
# polygons 4 19
# polygons 4 20
# polygons 4 21
# polygons 4 22
# polygons 4 23
# polygons 4 24
# polygons 4 25
# polygons 4 26
# polygons 4 27
# polygons 4 28
# polygons 4 29
# polygons 4 30
# polygons 4 31
# polygons 4 32
# polygons 4 33
# polygons 4 34
# polygons 4 35
# polygons 4 36
# polygons 4 37
# polygons 4 38
# polygons 4 39
# polygons 4 40
# polygons 5 0
# polygons 5 1
# polygons 5 2
# polygons 5 3
# polygons 5 4
# polygons 5 6
# polygons 5 7
# polygons 5 8
# polygons 5 9
# polygons 5 10
# polygons 5 11
# polygons 5 12
# polygons 5 13
# polygons 5 14
# polygons 5 15
# polygons 5 16
# polygons 5 17
# polygons 5 18
# polygons 5 19
# polygons 5 20
# polygons 5 21
# polygons 5 22
# polygons 5 23
# polygons 5 24
# polygons 5 25
# polygons 5 26
# polygons 5 27
# polygons 5 28
# polygons 5 29
# polygons 5 30
# polygons 5 31
# polygons 5 32
# polygons 5 33
# polygons 5 34
# polygons 5 35
# polygons 5 36
# polygons 5 37
# polygons 5 38
# polygons 5 39
# polygons 5 40
# polygons 6 0
# polygons 6 1
# polygons 6 2
# polygons 6 3
# polygons 6 4
# polygons 6 5
# polygons 6 7
# polygons 6 8
# polygons 6 9
# polygons 6 10
# polygons 6 11
# polygons 6 12
# polygons 6 13
# polygons 6 14
# polygons 6 15
# polygons 6 16
# polygons 6 17
# polygons 6 18
# polygons 6 19
# polygons 6 20
# polygons 6 21
# polygons 6 22
# polygons 6 23
# polygons 6 24
# polygons 6 25
# polygons 6 26
# polygons 6 27
# polygons 6 28
# polygons 6 29
# polygons 6 30
# polygons 6 31
# polygons 6 32
# polygons 6 33
# polygons 6 34
# polygons 6 35
# polygons 6 36
# polygons 6 37
# polygons 6 38
# polygons 6 39
# polygons 6 40
# polygons 7 0
# polygons 7 1
# polygons 7 2
# polygons 7 3
# polygons 7 4
# polygons 7 5
# polygons 7 6
# polygons 7 8
# polygons 7 9
# polygons 7 10
# polygons 7 11
# polygons 7 12
# polygons 7 13
# polygons 7 14
# polygons 7 15
# polygons 7 16
# polygons 7 17
# polygons 7 18
# polygons 7 19
# polygons 7 20
# polygons 7 21
# polygons 7 22
# polygons 7 23
# polygons 7 24
# polygons 7 25
# polygons 7 26
# polygons 7 27
# polygons 7 28
# polygons 7 29
# polygons 7 30
# polygons 7 31
# polygons 7 32
# polygons 7 33
# polygons 7 34
# polygons 7 35
# polygons 7 36
# polygons 7 37
# polygons 7 38
# polygons 7 39
# polygons 7 40
# polygons 8 0
# polygons 8 1
# polygons 8 2
# polygons 8 3
# polygons 8 4
# polygons 8 5
# polygons 8 6
# polygons 8 7
# polygons 8 9
# polygons 8 10
# polygons 8 11
# polygons 8 12
# polygons 8 13
# polygons 8 14
# polygons 8 15
# polygons 8 16
# polygons 8 17
# polygons 8 18
# polygons 8 19
# polygons 8 20
# polygons 8 21
# polygons 8 22
# polygons 8 23
# polygons 8 24
# polygons 8 25
# polygons 8 26
# polygons 8 27
# polygons 8 28
# polygons 8 29
# polygons 8 30
# polygons 8 31
# polygons 8 32
# polygons 8 33
# polygons 8 34
# polygons 8 35
# polygons 8 36
# polygons 8 37
# polygons 8 38
# polygons 8 39
# polygons 8 40
# polygons 9 0
# polygons 9 1
# polygons 9 2
# polygons 9 3
# polygons 9 4
# polygons 9 5
# polygons 9 6
# polygons 9 7
# polygons 9 8
# polygons 9 10
# polygons 9 11
# polygons 9 12
# polygons 9 13
# polygons 9 14
# polygons 9 15
# polygons 9 16
# polygons 9 17
# polygons 9 18
# polygons 9 19
# polygons 9 20
# polygons 9 21
# polygons 9 22
# polygons 9 23
# polygons 9 24
# polygons 9 25
# polygons 9 26
# polygons 9 27
# polygons 9 28
# polygons 9 29
# polygons 9 30
# polygons 9 31
# polygons 9 32
# polygons 9 33
# polygons 9 34
# polygons 9 35
# polygons 9 36
# polygons 9 37
# polygons 9 38
# polygons 9 39
# polygons 9 40
# polygons 10 0
# polygons 10 1
# polygons 10 2
# polygons 10 3
# polygons 10 4
# polygons 10 5
# polygons 10 6
# polygons 10 7
# polygons 10 8
# polygons 10 9
# polygons 10 11
# polygons 10 12
# polygons 10 13
# polygons 10 14
# polygons 10 15
# polygons 10 16
# polygons 10 17
# polygons 10 18
# polygons 10 19
# polygons 10 20
# polygons 10 21
# polygons 10 22
# polygons 10 23
# polygons 10 24
# polygons 10 25
# polygons 10 26
# polygons 10 27
# polygons 10 28
# polygons 10 29
# polygons 10 30
# polygons 10 31
# polygons 10 32
# polygons 10 33
# polygons 10 34
# polygons 10 35
# polygons 10 36
# polygons 10 37
# polygons 10 38
# polygons 10 39
# polygons 10 40
# polygons 11 0
# polygons 11 1
# polygons 11 2
# polygons 11 3
# polygons 11 4
# polygons 11 5
# polygons 11 6
# polygons 11 7
# polygons 11 8
# polygons 11 9
# polygons 11 10
# polygons 11 12
# polygons 11 13
# polygons 11 14
# polygons 11 15
# polygons 11 16
# polygons 11 17
# polygons 11 18
# polygons 11 19
# polygons 11 20
# polygons 11 21
# polygons 11 22
# polygons 11 23
# polygons 11 24
# polygons 11 25
# polygons 11 26
# polygons 11 27
# polygons 11 28
# polygons 11 29
# polygons 11 30
# polygons 11 31
# polygons 11 32
# polygons 11 33
# polygons 11 34
# polygons 11 35
# polygons 11 36
# polygons 11 37
# polygons 11 38
# polygons 11 39
# polygons 11 40
# polygons 12 0
# polygons 12 1
# polygons 12 2
# polygons 12 3
# polygons 12 4
# polygons 12 5
# polygons 12 6
# polygons 12 7
# polygons 12 8
# polygons 12 9
# polygons 12 10
# polygons 12 11
# polygons 12 13
# polygons 12 14
# polygons 12 15
# polygons 12 16
# polygons 12 17
# polygons 12 18
# polygons 12 19
# polygons 12 20
# polygons 12 21
# polygons 12 22
# polygons 12 23
# polygons 12 24
# polygons 12 25
# polygons 12 26
# polygons 12 27
# polygons 12 28
# polygons 12 29
# polygons 12 30
# polygons 12 31
# polygons 12 32
# polygons 12 33
# polygons 12 34
# polygons 12 35
# polygons 12 36
# polygons 12 37
# polygons 12 38
# polygons 12 39
# polygons 12 40
# polygons 13 0
# polygons 13 1
# polygons 13 2
# polygons 13 3
# polygons 13 4
# polygons 13 5
# polygons 13 6
# polygons 13 7
# polygons 13 8
# polygons 13 9
# polygons 13 10
# polygons 13 11
# polygons 13 12
# polygons 13 14
# polygons 13 15
# polygons 13 16
# polygons 13 17
# polygons 13 18
# polygons 13 19
# polygons 13 20
# polygons 13 21
# polygons 13 22
# polygons 13 23
# polygons 13 24
# polygons 13 25
# polygons 13 26
# polygons 13 27
# polygons 13 28
# polygons 13 29
# polygons 13 30
# polygons 13 31
# polygons 13 32
# polygons 13 33
# polygons 13 34
# polygons 13 35
# polygons 13 36
# polygons 13 37
# polygons 13 38
# polygons 13 39
# polygons 13 40
# polygons 14 0
# polygons 14 1
# polygons 14 2
# polygons 14 3
# polygons 14 4
# polygons 14 5
# polygons 14 6
# polygons 14 7
# polygons 14 8
# polygons 14 9
# polygons 14 10
# polygons 14 11
# polygons 14 12
# polygons 14 13
# polygons 14 15
# polygons 14 16
# polygons 14 17
# polygons 14 18
# polygons 14 19
# polygons 14 20
# polygons 14 21
# polygons 14 22
# polygons 14 23
# polygons 14 24
# polygons 14 25
# polygons 14 26
# polygons 14 27
# polygons 14 28
# polygons 14 29
# polygons 14 30
# polygons 14 31
# polygons 14 32
# polygons 14 33
# polygons 14 34
# polygons 14 35
# polygons 14 36
# polygons 14 37
# polygons 14 38
# polygons 14 39
# polygons 14 40
# polygons 15 0
# polygons 15 1
# polygons 15 2
# polygons 15 3
# polygons 15 4
# polygons 15 5
# polygons 15 6
# polygons 15 7
# polygons 15 8
# polygons 15 9
# polygons 15 10
# polygons 15 11
# polygons 15 12
# polygons 15 13
# polygons 15 14
# polygons 15 16
# polygons 15 17
# polygons 15 18
# polygons 15 19
# polygons 15 20
# polygons 15 21
# polygons 15 22
# polygons 15 23
# polygons 15 24
# polygons 15 25
# polygons 15 26
# polygons 15 27
# polygons 15 28
# polygons 15 29
# polygons 15 30
# polygons 15 31
# polygons 15 32
# polygons 15 33
# polygons 15 34
# polygons 15 35
# polygons 15 36
# polygons 15 37
# polygons 15 38
# polygons 15 39
# polygons 15 40
# polygons 16 0
# polygons 16 1
# polygons 16 2
# polygons 16 3
# polygons 16 4
# polygons 16 5
# polygons 16 6
# polygons 16 7
# polygons 16 8
# polygons 16 9
# polygons 16 10
# polygons 16 11
# polygons 16 12
# polygons 16 13
# polygons 16 14
# polygons 16 15
# polygons 16 17
# polygons 16 18
# polygons 16 19
# polygons 16 20
# polygons 16 21
# polygons 16 22
# polygons 16 23
# polygons 16 24
# polygons 16 25
# polygons 16 26
# polygons 16 27
# polygons 16 28
# polygons 16 29
# polygons 16 30
# polygons 16 31
# polygons 16 32
# polygons 16 33
# polygons 16 34
# polygons 16 35
# polygons 16 36
# polygons 16 37
# polygons 16 38
# polygons 16 39
# polygons 16 40
# polygons 17 0
# polygons 17 1
# polygons 17 2
# polygons 17 3
# polygons 17 4
# polygons 17 5
# polygons 17 6
# polygons 17 7
# polygons 17 8
# polygons 17 9
# polygons 17 10
# polygons 17 11
# polygons 17 12
# polygons 17 13
# polygons 17 14
# polygons 17 15
# polygons 17 16
# polygons 17 18
# polygons 17 19
# polygons 17 20
# polygons 17 21
# polygons 17 22
# polygons 17 23
# polygons 17 24
# polygons 17 25
# polygons 17 26
# polygons 17 27
# polygons 17 28
# polygons 17 29
# polygons 17 30
# polygons 17 31
# polygons 17 32
# polygons 17 33
# polygons 17 34
# polygons 17 35
# polygons 17 36
# polygons 17 37
# polygons 17 38
# polygons 17 39
# polygons 17 40
# polygons 18 0
# polygons 18 1
# polygons 18 2
# polygons 18 3
# polygons 18 4
# polygons 18 5
# polygons 18 6
# polygons 18 7
# polygons 18 8
# polygons 18 9
# polygons 18 10
# polygons 18 11
# polygons 18 12
# polygons 18 13
# polygons 18 14
# polygons 18 15
# polygons 18 16
# polygons 18 17
# polygons 18 19
# polygons 18 20
# polygons 18 21
# polygons 18 22
# polygons 18 23
# polygons 18 24
# polygons 18 25
# polygons 18 26
# polygons 18 27
# polygons 18 28
# polygons 18 29
# polygons 18 30
# polygons 18 31
# polygons 18 32
# polygons 18 33
# polygons 18 34
# polygons 18 35
# polygons 18 36
# polygons 18 37
# polygons 18 38
# polygons 18 39
# polygons 18 40
# polygons 19 0
# polygons 19 1
# polygons 19 2
# polygons 19 3
# polygons 19 4
# polygons 19 5
# polygons 19 6
# polygons 19 7
# polygons 19 8
# polygons 19 9
# polygons 19 10
# polygons 19 11
# polygons 19 12
# polygons 19 13
# polygons 19 14
# polygons 19 15
# polygons 19 16
# polygons 19 17
# polygons 19 18
# polygons 19 20
# polygons 19 21
# polygons 19 22
# polygons 19 23
# polygons 19 24
# polygons 19 25
# polygons 19 26
# polygons 19 27
# polygons 19 28
# polygons 19 29
# polygons 19 30
# polygons 19 31
# polygons 19 32
# polygons 19 33
# polygons 19 34
# polygons 19 35
# polygons 19 36
# polygons 19 37
# polygons 19 38
# polygons 19 39
# polygons 19 40
# polygons 20 0
# polygons 20 1
# polygons 20 2
# polygons 20 3
# polygons 20 4
# polygons 20 5
# polygons 20 6
# polygons 20 7
# polygons 20 8
# polygons 20 9
# polygons 20 10
# polygons 20 11
# polygons 20 12
# polygons 20 13
# polygons 20 14
# polygons 20 15
# polygons 20 16
# polygons 20 17
# polygons 20 18
# polygons 20 19
# polygons 20 21
# polygons 20 22
# polygons 20 23
# polygons 20 24
# polygons 20 25
# polygons 20 26
# polygons 20 27
# polygons 20 28
# polygons 20 29
# polygons 20 30
# polygons 20 31
# polygons 20 32
# polygons 20 33
# polygons 20 34
# polygons 20 35
# polygons 20 36
# polygons 20 37
# polygons 20 38
# polygons 20 39
# polygons 20 40
# polygons 21 0
# polygons 21 1
# polygons 21 2
# polygons 21 3
# polygons 21 4
# polygons 21 5
# polygons 21 6
# polygons 21 7
# polygons 21 8
# polygons 21 9
# polygons 21 10
# polygons 21 11
# polygons 21 12
# polygons 21 13
# polygons 21 14
# polygons 21 15
# polygons 21 16
# polygons 21 17
# polygons 21 18
# polygons 21 19
# polygons 21 20
# polygons 21 22
# polygons 21 23
# polygons 21 24
# polygons 21 25
# polygons 21 26
# polygons 21 27
# polygons 21 28
# polygons 21 29
# polygons 21 30
# polygons 21 31
# polygons 21 32
# polygons 21 33
# polygons 21 34
# polygons 21 35
# polygons 21 36
# polygons 21 37
# polygons 21 38
# polygons 21 39
# polygons 21 40
# polygons 22 0
# polygons 22 1
# polygons 22 2
# polygons 22 3
# polygons 22 4
# polygons 22 5
# polygons 22 6
# polygons 22 7
# polygons 22 8
# polygons 22 9
# polygons 22 10
# polygons 22 11
# polygons 22 12
# polygons 22 13
# polygons 22 14
# polygons 22 15
# polygons 22 16
# polygons 22 17
# polygons 22 18
# polygons 22 19
# polygons 22 20
# polygons 22 21
# polygons 22 23
# polygons 22 24
# polygons 22 25
# polygons 22 26
# polygons 22 27
# polygons 22 28
# polygons 22 29
# polygons 22 30
# polygons 22 31
# polygons 22 32
# polygons 22 33
# polygons 22 34
# polygons 22 35
# polygons 22 36
# polygons 22 37
# polygons 22 38
# polygons 22 39
# polygons 22 40
# polygons 23 0
# polygons 23 1
# polygons 23 2
# polygons 23 3
# polygons 23 4
# polygons 23 5
# polygons 23 6
# polygons 23 7
# polygons 23 8
# polygons 23 9
# polygons 23 10
# polygons 23 11
# polygons 23 12
# polygons 23 13
# polygons 23 14
# polygons 23 15
# polygons 23 16
# polygons 23 17
# polygons 23 18
# polygons 23 19
# polygons 23 20
# polygons 23 21
# polygons 23 22
# polygons 23 24
# polygons 23 25
# polygons 23 26
# polygons 23 27
# polygons 23 28
# polygons 23 29
# polygons 23 30
# polygons 23 31
# polygons 23 32
# polygons 23 33
# polygons 23 34
# polygons 23 35
# polygons 23 36
# polygons 23 37
# polygons 23 38
# polygons 23 39
# polygons 23 40
# polygons 24 0
# polygons 24 1
# polygons 24 2
# polygons 24 3
# polygons 24 4
# polygons 24 5
# polygons 24 6
# polygons 24 7
# polygons 24 8
# polygons 24 9
# polygons 24 10
# polygons 24 11
# polygons 24 12
# polygons 24 13
# polygons 24 14
# polygons 24 15
# polygons 24 16
# polygons 24 17
# polygons 24 18
# polygons 24 19
# polygons 24 20
# polygons 24 21
# polygons 24 22
# polygons 24 23
# polygons 24 25
# polygons 24 26
# polygons 24 27
# polygons 24 28
# polygons 24 29
# polygons 24 30
# polygons 24 31
# polygons 24 32
# polygons 24 33
# polygons 24 34
# polygons 24 35
# polygons 24 36
# polygons 24 37
# polygons 24 38
# polygons 24 39
# polygons 24 40
# polygons 25 0
# polygons 25 1
# polygons 25 2
# polygons 25 3
# polygons 25 4
# polygons 25 5
# polygons 25 6
# polygons 25 7
# polygons 25 8
# polygons 25 9
# polygons 25 10
# polygons 25 11
# polygons 25 12
# polygons 25 13
# polygons 25 14
# polygons 25 15
# polygons 25 16
# polygons 25 17
# polygons 25 18
# polygons 25 19
# polygons 25 20
# polygons 25 21
# polygons 25 22
# polygons 25 23
# polygons 25 24
# polygons 25 26
# polygons 25 27
# polygons 25 28
# polygons 25 29
# polygons 25 30
# polygons 25 31
# polygons 25 32
# polygons 25 33
# polygons 25 34
# polygons 25 35
# polygons 25 36
# polygons 25 37
# polygons 25 38
# polygons 25 39
# polygons 25 40
# polygons 26 0
# polygons 26 1
# polygons 26 2
# polygons 26 3
# polygons 26 4
# polygons 26 5
# polygons 26 6
# polygons 26 7
# polygons 26 8
# polygons 26 9
# polygons 26 10
# polygons 26 11
# polygons 26 12
# polygons 26 13
# polygons 26 14
# polygons 26 15
# polygons 26 16
# polygons 26 17
# polygons 26 18
# polygons 26 19
# polygons 26 20
# polygons 26 21
# polygons 26 22
# polygons 26 23
# polygons 26 24
# polygons 26 25
# polygons 26 27
# polygons 26 28
# polygons 26 29
# polygons 26 30
# polygons 26 31
# polygons 26 32
# polygons 26 33
# polygons 26 34
# polygons 26 35
# polygons 26 36
# polygons 26 37
# polygons 26 38
# polygons 26 39
# polygons 26 40
# polygons 27 0
# polygons 27 1
# polygons 27 2
# polygons 27 3
# polygons 27 4
# polygons 27 5
# polygons 27 6
# polygons 27 7
# polygons 27 8
# polygons 27 9
# polygons 27 10
# polygons 27 11
# polygons 27 12
# polygons 27 13
# polygons 27 14
# polygons 27 15
# polygons 27 16
# polygons 27 17
# polygons 27 18
# polygons 27 19
# polygons 27 20
# polygons 27 21
# polygons 27 22
# polygons 27 23
# polygons 27 24
# polygons 27 25
# polygons 27 26
# polygons 27 28
# polygons 27 29
# polygons 27 30
# polygons 27 31
# polygons 27 32
# polygons 27 33
# polygons 27 34
# polygons 27 35
# polygons 27 36
# polygons 27 37
# polygons 27 38
# polygons 27 39
# polygons 27 40
# polygons 28 0
# polygons 28 1
# polygons 28 2
# polygons 28 3
# polygons 28 4
# polygons 28 5
# polygons 28 6
# polygons 28 7
# polygons 28 8
# polygons 28 9
# polygons 28 10
# polygons 28 11
# polygons 28 12
# polygons 28 13
# polygons 28 14
# polygons 28 15
# polygons 28 16
# polygons 28 17
# polygons 28 18
# polygons 28 19
# polygons 28 20
# polygons 28 21
# polygons 28 22
# polygons 28 23
# polygons 28 24
# polygons 28 25
# polygons 28 26
# polygons 28 27
# polygons 28 29
# polygons 28 30
# polygons 28 31
# polygons 28 32
# polygons 28 33
# polygons 28 34
# polygons 28 35
# polygons 28 36
# polygons 28 37
# polygons 28 38
# polygons 28 39
# polygons 28 40
# polygons 29 0
# polygons 29 1
# polygons 29 2
# polygons 29 3
# polygons 29 4
# polygons 29 5
# polygons 29 6
# polygons 29 7
# polygons 29 8
# polygons 29 9
# polygons 29 10
# polygons 29 11
# polygons 29 12
# polygons 29 13
# polygons 29 14
# polygons 29 15
# polygons 29 16
# polygons 29 17
# polygons 29 18
# polygons 29 19
# polygons 29 20
# polygons 29 21
# polygons 29 22
# polygons 29 23
# polygons 29 24
# polygons 29 25
# polygons 29 26
# polygons 29 27
# polygons 29 28
# polygons 29 30
# polygons 29 31
# polygons 29 32
# polygons 29 33
# polygons 29 34
# polygons 29 35
# polygons 29 36
# polygons 29 37
# polygons 29 38
# polygons 29 39
# polygons 29 40
# polygons 30 0
# polygons 30 1
# polygons 30 2
# polygons 30 3
# polygons 30 4
# polygons 30 5
# polygons 30 6
# polygons 30 7
# polygons 30 8
# polygons 30 9
# polygons 30 10
# polygons 30 11
# polygons 30 12
# polygons 30 13
# polygons 30 14
# polygons 30 15
# polygons 30 16
# polygons 30 17
# polygons 30 18
# polygons 30 19
# polygons 30 20
# polygons 30 21
# polygons 30 22
# polygons 30 23
# polygons 30 24
# polygons 30 25
# polygons 30 26
# polygons 30 27
# polygons 30 28
# polygons 30 29
# polygons 30 31
# polygons 30 32
# polygons 30 33
# polygons 30 34
# polygons 30 35
# polygons 30 36
# polygons 30 37
# polygons 30 38
# polygons 30 39
# polygons 30 40
# polygons 31 0
# polygons 31 1
# polygons 31 2
# polygons 31 3
# polygons 31 4
# polygons 31 5
# polygons 31 6
# polygons 31 7
# polygons 31 8
# polygons 31 9
# polygons 31 10
# polygons 31 11
# polygons 31 12
# polygons 31 13
# polygons 31 14
# polygons 31 15
# polygons 31 16
# polygons 31 17
# polygons 31 18
# polygons 31 19
# polygons 31 20
# polygons 31 21
# polygons 31 22
# polygons 31 23
# polygons 31 24
# polygons 31 25
# polygons 31 26
# polygons 31 27
# polygons 31 28
# polygons 31 29
# polygons 31 30
# polygons 31 32
# polygons 31 33
# polygons 31 34
# polygons 31 35
# polygons 31 36
# polygons 31 37
# polygons 31 38
# polygons 31 39
# polygons 31 40
# polygons 32 0
# polygons 32 1
# polygons 32 2
# polygons 32 3
# polygons 32 4
# polygons 32 5
# polygons 32 6
# polygons 32 7
# polygons 32 8
# polygons 32 9
# polygons 32 10
# polygons 32 11
# polygons 32 12
# polygons 32 13
# polygons 32 14
# polygons 32 15
# polygons 32 16
# polygons 32 17
# polygons 32 18
# polygons 32 19
# polygons 32 20
# polygons 32 21
# polygons 32 22
# polygons 32 23
# polygons 32 24
# polygons 32 25
# polygons 32 26
# polygons 32 27
# polygons 32 28
# polygons 32 29
# polygons 32 30
# polygons 32 31
# polygons 32 33
# polygons 32 34
# polygons 32 35
# polygons 32 36
# polygons 32 37
# polygons 32 38
# polygons 32 39
# polygons 32 40
# polygons 33 0
# polygons 33 1
# polygons 33 2
# polygons 33 3
# polygons 33 4
# polygons 33 5
# polygons 33 6
# polygons 33 7
# polygons 33 8
# polygons 33 9
# polygons 33 10
# polygons 33 11
# polygons 33 12
# polygons 33 13
# polygons 33 14
# polygons 33 15
# polygons 33 16
# polygons 33 17
# polygons 33 18
# polygons 33 19
# polygons 33 20
# polygons 33 21
# polygons 33 22
# polygons 33 23
# polygons 33 24
# polygons 33 25
# polygons 33 26
# polygons 33 27
# polygons 33 28
# polygons 33 29
# polygons 33 30
# polygons 33 31
# polygons 33 32
# polygons 33 34
# polygons 33 35
# polygons 33 36
# polygons 33 37
# polygons 33 38
# polygons 33 39
# polygons 33 40
# polygons 34 0
# polygons 34 1
# polygons 34 2
# polygons 34 3
# polygons 34 4
# polygons 34 5
# polygons 34 6
# polygons 34 7
# polygons 34 8
# polygons 34 9
# polygons 34 10
# polygons 34 11
# polygons 34 12
# polygons 34 13
# polygons 34 14
# polygons 34 15
# polygons 34 16
# polygons 34 17
# polygons 34 18
# polygons 34 19
# polygons 34 20
# polygons 34 21
# polygons 34 22
# polygons 34 23
# polygons 34 24
# polygons 34 25
# polygons 34 26
# polygons 34 27
# polygons 34 28
# polygons 34 29
# polygons 34 30
# polygons 34 31
# polygons 34 32
# polygons 34 33
# polygons 34 35
# polygons 34 36
# polygons 34 37
# polygons 34 38
# polygons 34 39
# polygons 34 40
# polygons 35 0
# polygons 35 1
# polygons 35 2
# polygons 35 3
# polygons 35 4
# polygons 35 5
# polygons 35 6
# polygons 35 7
# polygons 35 8
# polygons 35 9
# polygons 35 10
# polygons 35 11
# polygons 35 12
# polygons 35 13
# polygons 35 14
# polygons 35 15
# polygons 35 16
# polygons 35 17
# polygons 35 18
# polygons 35 19
# polygons 35 20
# polygons 35 21
# polygons 35 22
# polygons 35 23
# polygons 35 24
# polygons 35 25
# polygons 35 26
# polygons 35 27
# polygons 35 28
# polygons 35 29
# polygons 35 30
# polygons 35 31
# polygons 35 32
# polygons 35 33
# polygons 35 34
# polygons 35 36
# polygons 35 37
# polygons 35 38
# polygons 35 39
# polygons 35 40
# polygons 36 0
# polygons 36 1
# polygons 36 2
# polygons 36 3
# polygons 36 4
# polygons 36 5
# polygons 36 6
# polygons 36 7
# polygons 36 8
# polygons 36 9
# polygons 36 10
# polygons 36 11
# polygons 36 12
# polygons 36 13
# polygons 36 14
# polygons 36 15
# polygons 36 16
# polygons 36 17
# polygons 36 18
# polygons 36 19
# polygons 36 20
# polygons 36 21
# polygons 36 22
# polygons 36 23
# polygons 36 24
# polygons 36 25
# polygons 36 26
# polygons 36 27
# polygons 36 28
# polygons 36 29
# polygons 36 30
# polygons 36 31
# polygons 36 32
# polygons 36 33
# polygons 36 34
# polygons 36 35
# polygons 36 37
# polygons 36 38
# polygons 36 39
# polygons 36 40
# polygons 37 0
# polygons 37 1
# polygons 37 2
# polygons 37 3
# polygons 37 4
# polygons 37 5
# polygons 37 6
# polygons 37 7
# polygons 37 8
# polygons 37 9
# polygons 37 10
# polygons 37 11
# polygons 37 12
# polygons 37 13
# polygons 37 14
# polygons 37 15
# polygons 37 16
# polygons 37 17
# polygons 37 18
# polygons 37 19
# polygons 37 20
# polygons 37 21
# polygons 37 22
# polygons 37 23
# polygons 37 24
# polygons 37 25
# polygons 37 26
# polygons 37 27
# polygons 37 28
# polygons 37 29
# polygons 37 30
# polygons 37 31
# polygons 37 32
# polygons 37 33
# polygons 37 34
# polygons 37 35
# polygons 37 36
# polygons 37 38
# polygons 37 39
# polygons 37 40
# polygons 38 0
# polygons 38 1
# polygons 38 2
# polygons 38 3
# polygons 38 4
# polygons 38 5
# polygons 38 6
# polygons 38 7
# polygons 38 8
# polygons 38 9
# polygons 38 10
# polygons 38 11
# polygons 38 12
# polygons 38 13
# polygons 38 14
# polygons 38 15
# polygons 38 16
# polygons 38 17
# polygons 38 18
# polygons 38 19
# polygons 38 20
# polygons 38 21
# polygons 38 22
# polygons 38 23
# polygons 38 24
# polygons 38 25
# polygons 38 26
# polygons 38 27
# polygons 38 28
# polygons 38 29
# polygons 38 30
# polygons 38 31
# polygons 38 32
# polygons 38 33
# polygons 38 34
# polygons 38 35
# polygons 38 36
# polygons 38 37
# polygons 38 39
# polygons 38 40
# polygons 39 0
# polygons 39 1
# polygons 39 2
# polygons 39 3
# polygons 39 4
# polygons 39 5
# polygons 39 6
# polygons 39 7
# polygons 39 8
# polygons 39 9
# polygons 39 10
# polygons 39 11
# polygons 39 12
# polygons 39 13
# polygons 39 14
# polygons 39 15
# polygons 39 16
# polygons 39 17
# polygons 39 18
# polygons 39 19
# polygons 39 20
# polygons 39 21
# polygons 39 22
# polygons 39 23
# polygons 39 24
# polygons 39 25
# polygons 39 26
# polygons 39 27
# polygons 39 28
# polygons 39 29
# polygons 39 30
# polygons 39 31
# polygons 39 32
# polygons 39 33
# polygons 39 34
# polygons 39 35
# polygons 39 36
# polygons 39 37
# polygons 39 38
# polygons 39 40
# polygons 40 0
# polygons 40 1
# polygons 40 2
# polygons 40 3
# polygons 40 4
# polygons 40 5
# polygons 40 6
# polygons 40 7
# polygons 40 8
# polygons 40 9
# polygons 40 10
# polygons 40 11
# polygons 40 12
# polygons 40 13
# polygons 40 14
# polygons 40 15
# polygons 40 16
# polygons 40 17
# polygons 40 18
# polygons 40 19
# polygons 40 20
# polygons 40 21
# polygons 40 22
# polygons 40 23
# polygons 40 24
# polygons 40 25
# polygons 40 26
# polygons 40 27
# polygons 40 28
# polygons 40 29
# polygons 40 30
# polygons 40 31
# polygons 40 32
# polygons 40 33
# polygons 40 34
# polygons 40 35
# polygons 40 36
# polygons 40 37
# polygons 40 38
# polygons 40 39
