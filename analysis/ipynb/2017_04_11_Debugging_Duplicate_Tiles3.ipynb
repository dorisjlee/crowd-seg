# %%
cd ../TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
# %pylab inline
from TileEM_plot_toolbox import *
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from BB2TileExact import *

# %%
DATA_DIR="../output_0/"
os.chdir(DATA_DIR)

# %%
ls
# Out:
# data.json   tiles2.pkl  tiles3.pkl  tiles4.pkl

# %% [markdown]
# ```
# $ python -i runIndicatorMat.py 20
# Creating Directory: output_0
#   0%|                                                                         | 0/47 [00:00<?, ?it/s]Working on Obj:  1
#  15%|█████████▊                                                       | 3/20 [00:00<00:01,  8.51it/s]No handlers could be found for logger "shapely.geos"
#  75%|████████████████████████████████████████████████                | 15/20 [49:31<16:30,  0.01it/s]Failed object : 1
#   2%|█▎                                                          | 1/47 [1:12:39<55:42:20,  0.00it/s]Working on Obj:  2
#   2%|█▎                                                            | 34/1553 [00:00<00:30, 49.40it/s]Duplicate tiles:  44 41 1.0
#  86%|███████████████████████████████████████████████████▉        | 1343/1553 [02:01<00:18, 11.06it/s]Duplicate tiles:  1352 27 0.321715816443
# Number of non-overlapping tile regions (M) :  2
# Number of workers (N) :  20
# Failed object : 2
#   4%|██▌                                                         | 2/47 [1:44:33<39:12:41,  0.00it/s]Working on Obj:  3
#   6%|███▉                                                          | 72/1140 [00:05<01:24, 12.67it/s]Duplicate tiles:  89 86 0.999999999999
#   8%|████▉                                                         | 90/1140 [00:10<02:06,  8.30it/s]Duplicate tiles:  90 87 0.353482103381
#  17%|██████████▌                                                  | 198/1140 [00:48<03:50,  4.09it/s]Duplicate tiles:  204 37 0.483362097037
#  27%|████████████████▎                                            | 306/1140 [01:25<03:54,  3.56it/s]Duplicate tiles:  308 33 0.365278343144
# Duplicate tiles:  308 34 0.231873826952
# Duplicate tiles:  308 35 0.339488555541
# Duplicate tiles:  309 24 0.836913176239
#  38%|███████████████████████                                      | 432/1140 [02:09<03:32,  3.33it/s]Duplicate tiles:  435 17 0.999999992905
# Duplicate tiles:  443 15 0.364731211931
# Duplicate tiles:  446 40 0.6521739116
#  90%|██████████████████████████████████████████████████████      | 1026/1140 [05:35<00:37,  3.06it/s]Duplicate tiles:  1032 75 0.675871621387
# Duplicate tiles:  1032 76 0.324128371876
# Number of non-overlapping tile regions (M) :  2
# Number of workers (N) :  20
# Failed object : 3
#   6%|███▊                                                        | 3/47 [2:05:00<30:33:26,  0.00it/s]Working on Obj:  4
#   2%|█▏                                                            | 34/1722 [00:00<00:33, 50.08it/s]Duplicate tiles:  44 0 0.999999998455
# Duplicate tiles:  47 14 0.999999957547
#   8%|████▊                                                        | 136/1722 [00:09<01:55, 13.72it/s]Duplicate tiles:  146 1 0.999999958647
#  11%|██████▌                                                      | 187/1722 [00:14<02:00, 12.73it/s]Duplicate tiles:  202 18 0.999999979997
#  12%|███████▏                                                     | 204/1722 [00:16<02:01, 12.52it/s]Duplicate tiles:  204 3 0.999999989716
#  24%|██████████████▍                                              | 408/1722 [00:35<01:53, 11.58it/s]Duplicate tiles:  422 9 0.79910261862
# Duplicate tiles:  423 9 0.200897281967
#  42%|█████████████████████████▉                                   | 731/1722 [01:05<01:28, 11.19it/s]Duplicate tiles:  743 12 0.626657487686
#  51%|███████████████████████████████▎                             | 884/1722 [01:19<01:15, 11.13it/s]Duplicate tiles:  896 6 0.33982637247
# Number of non-overlapping tile regions (M) :  2
# Number of workers (N) :  20
# Failed object : 4
#   9%|█████                                                       | 4/47 [2:52:11<30:50:59,  0.00it/s]Working on Obj:  5
#  60%|██████████████████████████████████████▍                         | 12/20 [03:23<02:15,  0.06it/s]Failed object : 5
#  11%|██████▍                                                     | 5/47 [2:59:04<25:04:10,  0.00it/s]Working on Obj:  6
#  50%|████████████████████████████████                                | 10/20 [00:02<00:02,  3.94it/s]Segmentation fault: 11
#  ```

# %%
t2 = pkl.load(open("tiles2.pkl"))

# %%
visualizeTilesSeparate(t2)
plt.ylim(300,450)
# Out:
# (300, 450)

# %%
duplicated_vtiles =compute_unique_tileset(t2)
# Out:
#  87%|████████▋ | 1344/1553 [02:12<00:20, 10.17it/s]
# Duplicate tiles:  44 41 1.0
# Duplicate tiles:
#  1352 27 0.321715816443

# %%
t3 = pkl.load(open("tiles3.pkl"))

# %%
visualizeTilesSeparate(t3)
plt.ylim(300,450)
# Out:
# (300, 450)

# %%
duplicated_vtiles =compute_unique_tileset(t3)
# Out:
#   7%|▋         | 84/1140 [00:10<02:07,  8.29it/s]
# Duplicate tiles:  89 86 0.999999999999
# Duplicate tiles:
#  17%|█▋        | 196/1140 [00:54<04:21,  3.61it/s]
#  90 87 0.353482103381
# Duplicate tiles:
#  27%|██▋       | 308/1140 [01:37<04:24,  3.15it/s]
#  204 37 0.483362097037
# Duplicate tiles:  308 33 0.365278343144
# Duplicate tiles:  308 34 0.231873826952
# Duplicate tiles:  308 35 0.339488555541
# Duplicate tiles:
#  38%|███▊      | 434/1140 [02:26<03:58,  2.96it/s]
#  309 24 0.836913176239
# Duplicate tiles:  435 17 0.999999992905
# Duplicate tiles:  443 15 0.364731211931
# Duplicate tiles:
#  90%|████████▉ | 1022/1140 [06:23<00:44,  2.66it/s]
#  446 40 0.6521739116
# Duplicate tiles:  1032 75 0.675871621387
# Duplicate tiles:
#  1032 76 0.324128371876

# %%
visualizeTilesSeparate(duplicated_vtiles[1])
plt.ylim(300,450)
# Out:
# (300, 450)

# %%
# DATA_DIR="output/"
# os.chdir(DATA_DIR)
#plot tile heatmap to see where duplication occurs

# %%
mkdir uniqified_output

# %%
cd ..
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
for objid in range(48):
    tile = pkl.load(open("output/tiles{}.pkl".format(objid)))

# %%
objid=15
tile = pkl.load(open("output/tiles{}.pkl".format(objid)))
duplicated,vtiles =compute_unique_tileset(tile)
# Out:
#   8%|▊         | 120/1590 [00:06<01:21, 17.95it/s]
# Duplicate tiles:  37 29 0.250543645775
# Duplicate tiles:
#  24%|██▎       | 375/1590 [00:24<01:19, 15.22it/s]
#  127 1 0.230748148368
# Duplicate tiles:
#  25%|██▌       | 405/1590 [00:26<01:18, 15.11it/s]ERROR:shapely.geos:TopologyException: found non-noded intersection between LINESTRING (393.282 53.8462, 396.667 50.8) and LINESTRING (396.636 50.8182, 396.667 50.8) at 396.66666666666669 50.800000000000011
#  375 32 0.380784780882
# Topological Error
#  29%|██▉       | 465/1590 [00:31<01:16, 14.69it/s]
#  410 36
# Duplicate tiles:
#  51%|█████     | 810/1590 [00:59<00:57, 13.68it/s]
#  477 30 0.438777980296
# Duplicate tiles:
#  52%|█████▏    | 825/1590 [01:00<00:55, 13.68it/s]
#  814 35 0.286615901261
# Duplicate tiles:
# ...

# %%
visualizeTilesSeparate(tile)

# %%
visualizeTilesSeparate(vtiles)

# %%
print "Duplication rate: ", (len(tile)-len(vtiles))/float(len(tile))
# Out:
#  Duplication rate:  0.976729559748

# %%
pkl.dump(open("uniqified_output/tiles{}.pkl".format(objid)))

# %%
objid=20
tile = pkl.load(open("output/tiles{}.pkl".format(objid)))
duplicated,vtiles =compute_unique_tileset(tile)
# Out:
#   2%|▏         | 28/1570 [00:00<00:25, 59.38it/s]
# Duplicate tiles:  31 28 0.975954790404
# Duplicate tiles:
#   3%|▎         | 42/1570 [00:01<00:46, 32.57it/s]
#  32 29 0.985484136187
# Duplicate tiles:
#   4%|▎         | 56/1570 [00:02<00:54, 27.58it/s]
#  55 30 0.571659885882
# Duplicate tiles:  58 2 0.648985416948
# Duplicate tiles:
#   4%|▍         | 70/1570 [00:02<01:01, 24.43it/s]
#  63 3 0.370139038342
# Duplicate tiles:  73 30 0.357495799755
# Duplicate tiles:
#   7%|▋         | 112/1570 [00:05<01:12, 19.98it/s]
#  78 4 0.441447697149
# Duplicate tiles:
#  25%|██▍       | 392/1570 [00:20<01:02, 18.98it/s]
#  113 21 0.314354302491
# Duplicate tiles:
#  31%|███       | 490/1570 [00:25<00:56, 19.12it/s]
#  403 21 0.473911631381
# Duplicate tiles:
#  32%|███▏      | 504/1570 [00:26<00:55, 19.11it/s]
#  501 23 0.789924147652
# Duplicate tiles:
#  33%|███▎      | 518/1570 [00:27<00:55, 19.09it/s]
#  512 18 0.255253270313
# Duplicate tiles:
# ...

# %%
visualizeTilesSeparate(tile)

visualizeTilesSeparate(vtiles)

print "Duplication rate: ", (len(tile)-len(vtiles))/float(len(tile))
# Out:
# Duplication rate:  0.98025477707

# %%
objid=25
tile = pkl.load(open("output/tiles{}.pkl".format(objid)))
duplicated,vtiles =compute_unique_tileset(tile)
# Out:
#  11%|█         | 300/2702 [01:02<08:22,  4.78it/s]
# Duplicate tiles:  73 62 0.22742114011
# Duplicate tiles:
#  14%|█▍        | 390/2702 [01:24<08:21,  4.61it/s]
#  301 47 0.326504550793
# Duplicate tiles:
#  29%|██▉       | 780/2702 [02:58<07:20,  4.37it/s]
#  401 57 0.753913206225
# Duplicate tiles:
#  39%|███▉      | 1065/2702 [04:07<06:20,  4.31it/s]
#  781 10 0.608901742666
# Duplicate tiles:
#  48%|████▊     | 1305/2702 [05:05<05:26,  4.28it/s]
#  1079 13 0.511754482818
# Duplicate tiles:
#  57%|█████▋    | 1545/2702 [06:02<04:31,  4.26it/s]
#  1308 48 0.85435559748
# Duplicate tiles:
#  58%|█████▊    | 1560/2702 [06:06<04:28,  4.26it/s]
#  1545 9 0.627937709496
# Duplicate tiles:  1564 54 0.319791028722
# Duplicate tiles:
#  84%|████████▍ | 2280/2702 [08:58<01:39,  4.23it/s]
#  1569 34 1.0
# Duplicate tiles:
#  2288 46 0.318780135769

# %%
visualizeTilesSeparate(tile)

visualizeTilesSeparate(vtiles)

print "Duplication rate: ", (len(tile)-len(vtiles))/float(len(tile))
# Out:
# Duplication rate:  0.972982975574

# %%
objid=21
tile = pkl.load(open("output/tiles{}.pkl".format(objid)))
duplicated,vtiles =compute_unique_tileset(tile)
visualizeTilesSeparate(tile)

visualizeTilesSeparate(vtiles)

print "Duplication rate: ", (len(tile)-len(vtiles))/float(len(tile))
# Out:
#   7%|▋         | 84/1124 [00:00<00:09, 106.47it/s]
# Duplicate tiles:  11 9 0.903055272017
# Duplicate tiles:
#  43%|████▎     | 480/1124 [00:04<00:05, 107.45it/s]
#  94 6 0.628973403397
# Duplicate tiles:
#  490 3 0.993368927925
# Duplication rate:  0.990213523132
