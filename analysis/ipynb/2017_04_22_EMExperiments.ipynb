# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
# %load_ext autoreload
# %autoreload 2
from TileEM import *
from Qj_pTprime_models import *

# %%
objid=23
tiles = np.array(pkl.load(open(DATA_DIR+"/vtiles{}.pkl".format(objid))))
visualizeTilesSeparate(tiles)

# %%
objid=47
indMat = pkl.load(open(DATA_DIR+"/indMat{}.pkl".format(objid)))
Tprime_lst = Tprime_snowball_area(objid,indMat,fixedtopk=3, topk = 40,NTprimes=1000)
tiles = np.array(pkl.load(open(DATA_DIR+"/vtiles{}.pkl".format(objid))))

# %%
for Tprime in Tprime_lst:
    visualizeTilesSeparate(tiles[Tprime])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-8823d7d1a0b4> in <module>()
#       1 for Tprime in Tprime_lst:
# ----> 2     visualizeTilesSeparate(tiles[Tprime])
#
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/BB2TileExact.pyc in visualizeTilesSeparate(tiles, colorful)
#     180             c="lime"
#     181         if type(t)==shapely.geometry.polygon.Polygon:
# --> 182             plot_coords(t,color=c,reverse_xy=True,fill_color=c)
#     183         elif type(t)==shapely.geometry.MultiPolygon or type(t)==shapely.geometry.collection:
#     184             for region in t:
#
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/BB2TileExact.pyc in plot_coords(obj, color, reverse_xy, linestyle, fill_color)
#     278             y,x = ob.exterior.xy
#     279         plt.plot(x, y, linestyle, color=color, zorder=1)
# ...

# %%
DATA_DIR="sampletopworst5"
pTprime_lst,T_lst = runTileEM(47,Tprime_snowball_area,pTprimeGTLSA,QjGTLSA,A_percentile=99,\
                                             Niter=5,NTprimes=100,PLOT_LIKELIHOOD=True,DEBUG=True)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Coming up with T' combinations to search through
# E-step : Estimate Qj parameters
# Mstep: Picking the max-likelihood T'
# Likelihood:-51.6768192049 ; T=[39, 107, 95, 109]
#  20%|██        | 1/5 [00:12<00:48,  0.08it/s]
# E-step : Estimate Qj parameters
# Mstep: Picking the max-likelihood T'
# Likelihood:-30.5526800782 ; T=[39, 107, 95, 109]
#  40%|████      | 2/5 [00:49<01:14,  0.04it/s]
# E-step : Estimate Qj parameters
# Mstep: Picking the max-likelihood T'
# Likelihood:-30.5526800782 ; T=[39, 107, 95, 109]
#  60%|██████    | 3/5 [01:27<00:58,  0.03it/s]
# E-step : Estimate Qj parameters
# Mstep: Picking the max-likelihood T'
# Likelihood:-30.5526800782 ; T=[39, 107, 95, 109]
#  80%|████████  | 4/5 [02:06<00:31,  0.03it/s]
# E-step : Estimate Qj parameters
# Mstep: Picking the max-likelihood T'
# Likelihood:-30.5526800782 ; T=[39, 107, 95, 109]

# %%
for pTprime in pTprime_lst:
    print max(pTprime)
    plt.plot(max(pTprime))
# Out:
# -51.6768192049
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782

# %%
exp_num =1 #experiment number

# %%
pkl.dump(pTprime_lst,open("pTprime_exp#{0}_obj{1}.pkl".format(exp_num,objid),'w'))
pkl.dump(T_lst,open("pTprime_exp#{}_obj{1}.pkl".format(exp_num,objid),'w'))
pkl.dump(ML_lst,open("pTprime_exp#{}_obj{1}.pkl".format(exp_num,objid),'w'))

# %%
pTprime_lst[3]==pTprime_lst[4]
# Out:
# True

# %%
likelihood_lst
# Out:
# [-51.676819204890769,
#  -30.552680078150992,
#  -30.552680078150992,
#  -30.552680078150992,
#  -30.552680078150992]

# %%
for pTprime in pTprime_lst:
    plt.figure()
    plt.hist(pTprime,bins=50)

# %%
pkl.dump(pTprime_lst,open("pTprime_lst.pkl",'w'))

# %%
pTprime1 = pkl.load(open("pTprime_lst.pkl"))

# %%
pTprimeLst = pkl.load(open("pTprime_exp#1_obj3.pkl"))

# %%
plt.plot(pTprime)

# %%
for pTprime in pTprimeLst:
    print max(pTprime)
    plt.plot(max(pTprime))
# Out:
# -178.452950225
# -159.34373008
# -159.34373008
# -159.34373008
# -159.34373008

# %%
pTprimeLst = pkl.load(open("pTprime_exp#2_obj14.pkl"))
pTprimeLst2 = pkl.load(open("pTprime_exp#2_obj3.pkl"))
pTprimeLst3 = pkl.load(open("pTprime_exp#2_obj47.pkl"))

# %%
for pTprime in pTprimeLst:
    print max(pTprime)
    plt.plot(max(pTprime))
# Out:
# -46.1259839343
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879
# -34.3717650879

# %%
for pTprime in pTprimeLst2:
    print max(pTprime)
    plt.plot(max(pTprime))
# Out:
# -48.6716021499
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608
# -36.7894542608

# %%
for pTprime in pTprimeLst3:
    print max(pTprime)
    plt.plot(max(pTprime))
# Out:
# -51.3102098738
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782
# -30.5526800782

# %%
pTprimeLst[2]==pTprimeLst[-1]
# Out:
# True

# %%
for pTprime in pTprimeLst:
    plt.figure()
    plt.hist(pTprime,bins=50)

# %%
T_lst1 = pkl.load(open("T_lst_exp#2_obj14.pkl"))
T_lst2 = pkl.load(open("T_lst_exp#2_obj3.pkl"))
T_lst3 = pkl.load(open("T_lst_exp#2_obj47.pkl"))
