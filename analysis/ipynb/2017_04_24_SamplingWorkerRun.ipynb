# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
from  analysis_toolbox import *

# %%
img_info,object_tbl,bb_info,hit_info = load_info()

# %%
print bb_info.groupby(["object_id"]).count()["worker_id"]
# Out:
# object_id
# 1     34
# 2     37
# 3     39
# 4     40
# 5     39
# 6     40
# 7     40
# 8     38
# 9     40
# 10    41
# 11    41
# 12    41
# 13    39
# 14    39
# 15    41
# 16    37
# 17    44
# 18    39
# 19    42
# 20    41
# 21    40
# 22    40
# 23    38
# 24    39
# 25    39
# 26    37
# 27    40
# 28    34
# 29    36
# 30    35
# 31    40
# 32    34
# 33    40
# 34    38
# 35    35
# 36    39
# 37    37
# 38    38
# 39    40
# 40    40
# 41    38
# 42    40
# 43    41
# 44    40
# 45    39
# 46    39
# 47    40
# Name: worker_id, dtype: int64

# %%
cd sample/output_6/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/sample/output_6

# %%
from BB2TileExact import *

# %%
for objid in list(object_tbl.id):
    tiles = pkl.load(open("vtiles{}.pkl".format(objid)))
    visualizeTilesSeparate(tiles)

# %%
cd ../output_7/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/sample/output_7

# %%
for objid in list(object_tbl.id):
    tiles = pkl.load(open("vtiles{}.pkl".format(objid)))
    visualizeTilesSeparate(tiles)
