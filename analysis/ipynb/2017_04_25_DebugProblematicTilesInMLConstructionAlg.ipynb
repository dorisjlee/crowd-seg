# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
from BB2TileExact import *

# %%
tiles=pkl.load(open("output_26/vtiles10.pkl"))

# %%
len(tiles)
# Out:
# 880

# %% [markdown]
# # The union step in for adding tk in T* often fails

# %%
visualizeTilesSeparate(tiles)

# %%
for objid in list(object_tbl.id):
    tiles=pkl.load(open("output_25/vtiles{}.pkl".format(objid)))
    visualizeTilesSeparate(tiles)
    plt.title("Obj#{0};N={1};".format(objid,len(tiles)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-ce6031f19647> in <module>()
#       1 for objid in list(object_tbl.id):
#       2     tiles=pkl.load(open("output_25/vtiles{}.pkl".format(objid)))
# ----> 3     visualizeTilesSeparate(tiles)
#       4     plt.title("Obj#{0};N={1};".format(objid,len(tiles)))
#
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM/BB2TileExact.pyc in visualizeTilesSeparate(tiles, colorful)
#     182             c="lime"
#     183         if type(t)==shapely.geometry.polygon.Polygon:
# --> 184             plot_coords(t,color=c,reverse_xy=True,fill_color=c)
#     185         elif type(t)==shapely.geometry.MultiPolygon or type(t)==shapely.geometry.collection:
#     186             for region in t:
#
# ...

# %%
objid=35
tiles=pkl.load(open("output_25/vtiles{}.pkl".format(objid)))
visualizeTilesSeparate(tiles)
plt.title("Obj#{0};N={1};".format(objid,len(tiles)))
plt.ylim(100,650)
# Out:
# (100, 650)

# %%
a = pkl.load(open("a.pkl"))
b = pkl.load(open("b.pkl"))

# %%
a.buffer(0)

# %%
a.buffer(0).union(b)

# %%
a.area
# Out:
# 54.684484104395324

# %%
b.area
# Out:
# 0.4134152602661472

# %%
type(a)
# Out:
# shapely.geometry.collection.GeometryCollection

# %%
type(b)
# Out:
# shapely.geometry.polygon.Polygon

# %%
b.buffer(-1e-10)

# %%
a = pkl.load(open("a.pkl"))
b = pkl.load(open("b.pkl"))

# %%
a

# %%
b

# %%
a.area
# Out:
# 285.1170077218257

# %%
a.buffer(-1e-10).area
# Out:
# 285.11700763229624

# %%
a.buffer(-1e-10).union(b.buffer(0))

# %%
a = pkl.load(open("a.pkl"))

# %%
a

# %%
a0 = a[0]

# %%
a0.is_valid
# Out:
# True

# %%
a[0].buffer(0)

# %%
len(pkl.load(open("output_25/vtiles9.pkl")))
# Out:
# 504

# %%
tk = pkl.load(open("problematic_tk_1173.pkl"))
Tstar = pkl.load(open("problematic_Tstar_1173.pkl"))

# %%
Tstar

# %%
Tstar.area
# Out:
# 102825.25954058437

# %%
tk.area
# Out:
# 21.95784210988186

# %%
Tstar.union(tk.buffer(1e-10)).area
# Out:
# 102845.55239358821

# %%
Tstar.union(tk.buffer(1e-10))

# %%
objid=35
tiles=pkl.load(open("output_15/vtiles{}.pkl".format(objid)))
visualizeTilesSeparate(tiles)
plt.title("Obj#{0};N={1};".format(objid,len(tiles)))
plt.ylim(100,650)
# Out:
# (100, 650)

# %%
tk = pkl.load(open("problematic_tk_365.pkl"))
Tstar = pkl.load(open("problematic_Tstar_365.pkl"))

# %%
Tstar

# %%
Tstar.buffer(1e-10)

# %%
tk

# %%
Tstar.buffer(1e-10).union(tk)

# %%
tk = pkl.load(open("problematic_tk_414.pkl"))
Tstar = pkl.load(open("problematic_Tstar_414.pkl"))

# %%
tk

# %%
tk

# %%
Tstar.buffer(1e-8).union(tk)

# %%
Tstar.buffer(1e-10).union(tk.buffer(1e-10))
# Out:
# ERROR:shapely.geos:TopologyException: Input geom 0 is invalid: Self-intersection at or near point 206.8006020697274 428.20025802988317 at 206.8006020697274 428.20025802988317
# WARNING:shapely.geos:Self-intersection at or near point 206.8006020697274 428.20025802988317
# ---------------------------------------------------------------------------
# TopologicalError                          Traceback (most recent call last)
# <ipython-input-130-eee989be19de> in <module>()
# ----> 1 Tstar.buffer(1e-10).union(tk.buffer(1e-10))
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/shapely/geometry/base.pyc in union(self, other)
#     627     def union(self, other):
#     628         """Returns the union of the geometries (Shapely geometry)"""
# --> 629         return geom_factory(self.impl['union'](self, other))
#     630
#     631     # Unary predicates
#
# ...

# %%
tk = pkl.load(open("problematic_tk_416.pkl"))
Tstar = pkl.load(open("problematic_Tstar_416.pkl"))
