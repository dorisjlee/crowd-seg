# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
# %load_ext autoreload
# %autoreload 2
from TileEM import *
from Qj_pTprime_models import *

# %%
DATA_DIR="final_all_tiles"

# %% [markdown]
# # M step first

# %%
# Qj_lst = pkl.load(open("Qj_new"))
# T_lst = pkl.load(open("T_lst_new"))
# Tprime_lst = pkl.load(open("Tprime_new.pkl"))
# pTprimeLst = pkl.load(open("pTprime_new.pkl"))

# %%
Qj_lst = pkl.load(open("Qj_exp9_obj3.pkl"))
T_lst = pkl.load(open("T_lst_exp9_obj3.pkl"))
Tprime_lst = pkl.load(open("Tprime_exp9_obj3.pkl"))
pTprimeLst = pkl.load(open("pTprime_exp9_obj3.pkl"))

# %%
len(Qj_lst)
# Out:
# 5

# %% [markdown]
# ### Worker Quality distribution

# %%
Qj_lst[0]==Qj_lst[-1]
# Out:
# False

# %%
Qj_lst[1]==Qj_lst[-1]
# Out:
# True

# %% [markdown]
# #### Worker quality doesn't change overtime, initialized 0.5

# %% [markdown]
# __q0,q1,q2,q3= qp1,qp2,qn1,qn2__

# %%
for Qj in Qj_lst:
    Qjs = zip(*Qj)
    plt.figure()
    for i in range(len(Qjs)):
        plt.hist(Qjs[i],bins=len(Qj),label="Q{}".format(i))
        plt.legend(loc= "top left")
    plt.xlim(0,1.1)

# %%
pTprimeLst[1]==pTprimeLst[-1]
# Out:
# False

# %%
# for pTprime in pTprimeLst:
#     plt.figure()
#     plt.hist(pTprime,bins=50)

# %% [markdown]
# #### Likelihood plot

# %%
plt.plot(np.max(pTprimeLst,axis=1))

# %%
tiles=np.array(pkl.load(open("final_all_tiles/vtiles3.pkl")))

# %%
visualizeTilesSeparate(tiles)

# %%
for Tprime in T_lst:
    visualizeTilesSeparate(tiles[Tprime])

# %%
for T in T_lst:
    print T
# Out:
# [2955, 2635, 2548, 3192, 2287, 1990, 2189, 1985, 2862, 2800, 3066, 3148, 3190, 2555, 2188, 2291, 2798, 3061, 2797, 3193, 1988, 3508, 2338, 3509]
# [3190, 2549, 2188, 3510, 2189, 1988, 3148, 2883, 2291, 2798, 2548, 3192, 3193, 2862, 3191, 2797, 2555, 2317, 2955, 2287, 3061, 3151, 3066, 1985, 800, 2800, 1939, 1990, 3508, 2338, 3509]
# [3190, 2549, 2188, 3510, 2189, 1988, 3148, 2883, 2291, 2798, 2548, 3192, 3193, 2862, 3191, 2797, 2555, 2317, 2955, 2287, 3061, 3151, 3066, 1985, 800, 2800, 1939, 1990, 3508, 2338, 3509]
# [3190, 2549, 2188, 3510, 2189, 1988, 3148, 2883, 2291, 2798, 2548, 3192, 3193, 2862, 3191, 2797, 2555, 2317, 2955, 2287, 3061, 3151, 3066, 1985, 800, 2800, 1939, 1990, 3508, 2338, 3509]
# [3190, 2549, 2188, 3510, 2189, 1988, 3148, 2883, 2291, 2798, 2548, 3192, 3193, 2862, 3191, 2797, 2555, 2317, 2955, 2287, 3061, 3151, 3066, 1985, 800, 2800, 1939, 1990, 3508, 2338, 3509]

# %%
# print Tprime_lst

# %% [markdown]
# # Experiment 10: E step initialization first

# %% [markdown]
# # Experiment 12 : ML construction

# %%
ls *exp12*
# Out:
# Qj_exp12_obj9.pkl         Tstar_exp12_obj9.pkl      Tstar_idx_exp12_obj9.pkl

# %%
Qj_lst = pkl.load(open("Qj_exp12_obj9.pkl"))
T_lst = pkl.load(open("Tstar_exp12_obj9.pkl"))
Tstar_idx_lst = pkl.load(open("Tstar_idx_exp12_obj9.pkl"))

# %%
for Qj in Qj_lst:
    Qjs = zip(*Qj)
    plt.figure()
    for i in range(len(Qjs)):
        plt.hist(Qjs[i],bins=len(Qj),label="Q{}".format(i))
        plt.legend(loc= "top left")
    plt.xlim(0,1.1)

# %%
tiles=np.array(pkl.load(open("output_25/vtiles9.pkl")))

# %%
visualizeTilesSeparate(tiles)

# %%
for T  in T_lst:
    visualizeTilesSeparate(T[0])

# %%
for idx  in Tstar_idx_lst:
    visualizeTilesSeparate(tiles[idx])

# %% [markdown]
# # Experiment 13 : ML construction with likelihood score

# %%
Qj_lst = pkl.load(open("Qj_exp13_obj35.pkl"))
T_lst = pkl.load(open("Tstar_exp13_obj35.pkl"))
Tstar_idx_lst = pkl.load(open("Tstar_idx_exp13_obj35.pkl"))
likelihood_lst = pkl.load(open("likelihood_exp13_obj35.pkl"))

# %%
for Qj in Qj_lst:
    Qjs = zip(*Qj)
    plt.figure()
    for i in range(len(Qjs)):
        plt.hist(Qjs[i],bins=len(Qj),label="Q{}".format(i))
        plt.legend(loc= "top left")
    plt.xlim(0,1.1)

# %% [markdown]
# # Plot BBG against GT

# %%
objid=35
my_BBG  = pd.read_csv("my_ground_truth.csv")
ground_truth_match = my_BBG[my_BBG.object_id==objid]
x_locs,y_locs =  process_raw_locs([ground_truth_match["x_locs"].iloc[0],ground_truth_match["y_locs"].iloc[0]])
BBG = shapely.geometry.Polygon(zip(x_locs,y_locs))

# %% [markdown]
# #### plotting joined tiles T*

# %%
for T  in T_lst:
    visualizeTilesSeparate(T[0])
    plot_coords(BBG,reverse_xy=True)

# %% [markdown]
# #### plotting unjoined tiles in T*

# %%
tiles=np.array(pkl.load(open("output_15/vtiles35.pkl")))

# %%
for Tidx  in Tstar_idx_lst:
    visualizeTilesSeparate(tiles[Tidx])
    plot_coords(BBG,reverse_xy=True)

# %%
plt.plot(likelihood_lst)
plt.ylabel("Likelihood")
plt.xlabel("Iterations")

# %% [markdown]
# ##### Time Elapsed:  406.961754084

# %% [markdown]
# # Experiment 14: Running on an object that is just precision error no logical error

# %%
tiles=pkl.load(open("output_15/vtiles26.pkl"))

# %%
visualizeTilesSeparate(tiles)

# %%
Qj_lst = pkl.load(open("Qj_exp14_obj26.pkl"))
T_lst = pkl.load(open("Tstar_exp14_obj26.pkl"))
Tstar_idx_lst = pkl.load(open("Tstar_idx_exp14_obj26.pkl"))
likelihood_lst = pkl.load(open("likelihood_exp14_obj26.pkl"))

# %%
for Qj in Qj_lst:
    Qjs = zip(*Qj)
    plt.figure()
    for i in range(len(Qjs)):
        plt.hist(Qjs[i],bins=len(Qj),label="Q{}".format(i))
        plt.legend(loc= "top left")
    plt.xlim(0,1.1)

# %%
objid=26
my_BBG  = pd.read_csv("my_ground_truth.csv")
ground_truth_match = my_BBG[my_BBG.object_id==objid]
x_locs,y_locs =  process_raw_locs([ground_truth_match["x_locs"].iloc[0],ground_truth_match["y_locs"].iloc[0]])
BBG = shapely.geometry.Polygon(zip(x_locs,y_locs))

# %%
tiles=np.array(pkl.load(open("output_15/vtiles{}.pkl".format(objid))))
for Tidx  in Tstar_idx_lst:
    visualizeTilesSeparate(tiles[Tidx])
    plot_coords(BBG,reverse_xy=True,color="blue",linestyle="--")
    plt.ylim(480,170)

# %%
plt.plot(likelihood_lst)
plt.ylabel("Likelihood")
plt.xlabel("Iterations")

# %%
Tstar = pkl.load(open("Tstar_exp0_obj26.pkl"))

# %%
visualizeTilesSeparate(Tstar[0][0])
plot_coords(BBG,reverse_xy=True,color="blue",linestyle="--")
