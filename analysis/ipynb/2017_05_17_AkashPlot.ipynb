# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
from analysis_toolbox import *
# Out:
# qualityBaseline.py:225: SyntaxWarning: import * only allowed at module level
#   def compute_my_COCO_BBvals(compute_metrics=['simple','area','dist']):

# %%
cd ..
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis

# %%
visualize_bb_worker(15)

# %% [markdown]
# # Worker Responses

# %% [markdown]
# (a) first showing a few worker bounding boxes on the actual image separately, and

# %% [markdown]
# (b) then showing one with them all superimposed on the actual image.

# %%
visualize_bb_objects(8,gtypes=['worker'])

# %% [markdown]
# # Ground Truth

# %%
visualize_bb_objects(8,gtypes=['self'])

# %%
visualize_bb_objects(8,gtypes=['self','worker'])

# %% [raw]
# For (2), I was thinking about
# (c) Then showing one without the original background image, but with all the tiles (potentially color-filled so it doesn't look too messy)?
# (d) and then one pInT pixel map to say that this is what our final output will look like

# %%
cd TileEM/
# Out:
# /Users/dorislee/Desktop/Research/seg/crowd-seg/analysis/TileEM

# %%
from BB2TileExact import *

# %%
visualizeTilesSeparate()
